# %% [markdown]
# # Train Log 20181206
#
# * Add multi-model training structure
#
# ## Results
# ```
#
# ```
#
# ## Trained model
# * [Download link]()
#
# ## Evaluation
# * Incorrect sample
# ![results]()

# %%
import os, sys
import numpy as np
import matplotlib.pyplot as plt
import time , datetime

# sys.path.append( os.path.abspath('../../../Dataset/scripts'))
# from utils import *

sys.path.append( os.path.abspath('../../model') )
from train import *

import multiprocessing

import tensorflow as tf

# %%
""" Path """
data_train_path = os.path.abspath('../../../new_dataset/dataset/dataset_20181203_01/train.h5')
data_vali_path = os.path.abspath('../../../new_dataset/dataset/dataset_20181203_01/vali.h5')

# %%
""" Load dataset"""

data = []
class_label = []
heading_label = []

def load_h5(h5_filename):
    f = h5py.File(h5_filename)
    data = f['data'][:]
    class_label = f['class'][:]
    heading_label = f['heading'][:]
    return (data, class_label, heading_label)

data_train, class_label_train, heading_label_train = load_h5(data_train_path)
data_vali, class_label_vali, heading_label_vali = load_h5(data_vali_path)

data.append(data_train)
data.append(data_vali)
class_label.append(class_label_train)
class_label.append(class_label_vali)
heading_label.append(heading_label_train)
heading_label.append(heading_label_vali)

""" Data statistics """

label_list = [0,1,2]

y_val = []
for i in range( len ( data) ):
    for j in range ( len ( label_list ) ):
        y_val.append(np.sum(class_label[i] == label_list[j]))

x_name=('unknown-train', 'cars-train','pedestrian-train',
        'unknown-vali', 'cars-vali', 'pedestrian-vali')

index = range( len(x_name) )

plt.figure(figsize=(15,5))
plt.bar(index, y_val, tick_label=x_name, align='center')
plt.ylabel('Number of dataset')
plt.title('Label distribution')
plt.xlim( -1, len(x_name))
plt.ylim( 0, np.max(y_val) * 1.1 )
plt.show()

# %%
import os, sys

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import explained_variance_score, mean_squared_error, mean_absolute_error, r2_score

"""
Import model 
"""
sys.path.append( os.path.abspath('../../model') )

from train import *
import model_out_5_heading_3_sigmoid as MODEL



def run_training(out_path):
    
    """ Path """
    model_save_path = os.path.abspath(out_path)
    if not os.path.isdir(model_save_path) : os.mkdir(model_save_path)
        
    """ Parameters """
    GPU_INDEX = 0
    NUM_POINT = 1024
    NUM_CLASSES = 3

    BN_INIT_DECAY = 0.5
    BN_DECAY_DECAY_RATE = 0.5
    BN_DECAY_DECAY_STEP = float(200000)
    BN_DECAY_CLIP = 0.99
    DECAY_STEP = BN_DECAY_DECAY_STEP
    DECAY_RATE = BN_DECAY_DECAY_RATE

    BATCH_SIZE = 50

    MOMENTUM = 0.9

    BASE_LEARNING_RATE = 0.001

    OPTIMIZER = 'adam'

    MAX_EPOCH = 10
    
    HEADING_LOSS_WEIGHT = 10.0


    
    def get_learning_rate(batch):
        learning_rate = tf.train.exponential_decay(
                            BASE_LEARNING_RATE,  # Base learning rate.
                            batch * BATCH_SIZE,  # Current index into the dataset.
                            DECAY_STEP,          # Decay step.
                            DECAY_RATE,          # Decay rate.
                            staircase=True)
        learning_rate = tf.maximum(learning_rate, 0.00001) # CLIP THE LEARNING RATE!
        return learning_rate        

    def get_bn_decay(batch):
        bn_momentum = tf.train.exponential_decay(
                          BN_INIT_DECAY,
                          batch * BATCH_SIZE,
                          BN_DECAY_DECAY_STEP,
                          BN_DECAY_DECAY_RATE,
                          staircase=True)
        bn_decay = tf.minimum(BN_DECAY_CLIP, 1 - bn_momentum)
        return bn_decay

    
    """
    load traing model
    """
    with tf.Graph().as_default():
        with tf.device('/gpu:'+str(GPU_INDEX)):
            
            
            """
            Placeholder
            """
            pointclouds_pl, class_labels_pl, heading_labels_pl = MODEL.placeholder_inputs(BATCH_SIZE, NUM_POINT)
            is_training_pl = tf.placeholder(tf.bool, shape=())
            print(is_training_pl)

            
            """
            decay
            """
            # Note the global_step=batch parameter to minimize. 
            # That tells the optimizer to helpfully increment the 'batch' parameter for you every time it trains.
            batch = tf.Variable(0)
            bn_decay = get_bn_decay(batch)
            tf.summary.scalar('bn_decay', bn_decay)
            
            
            """
            Get model and loss 
            """
            pred, end_points = MODEL.get_model(pointclouds_pl, is_training_pl, bn_decay=bn_decay)
            loss = MODEL.get_loss(pred, class_labels_pl, heading_labels_pl, end_points, h_reg_weight=HEADING_LOSS_WEIGHT)
            tf.summary.scalar('loss', loss)
            
            classify_loss = MODEL.get_classify_loss(pred, class_labels_pl)
            mat_diff_loss = MODEL.get_mat_diff_loss(end_points)
            heading_loss = MODEL.get_heading_loss(pred, heading_labels_pl)
            
            tf.summary.scalar('classify_loss', classify_loss)
            tf.summary.scalar('mat_diff_loss', mat_diff_loss)
            tf.summary.scalar('heading_loss', heading_loss)

            
            """
            Get accuracy 
            """
            correct = tf.equal(tf.argmax(tf.slice(pred, [0,0], [BATCH_SIZE,3]), 1), tf.to_int64(class_labels_pl))
            accuracy = tf.reduce_sum(tf.cast(correct, tf.float32)) / float(BATCH_SIZE)
            tf.summary.scalar('accuracy', accuracy)

            
            """
            Get training operator
            """
            learning_rate = get_learning_rate(batch)
            tf.summary.scalar('learning_rate', learning_rate)
            if OPTIMIZER == 'momentum':
                optimizer = tf.train.MomentumOptimizer(learning_rate, momentum=MOMENTUM)
            elif OPTIMIZER == 'adam':
                optimizer = tf.train.AdamOptimizer(learning_rate)
            train_op = optimizer.minimize(loss, global_step=batch)

            
            """
            Add ops to save and restore all the variables.
            """
            saver = tf.train.Saver()

            
        """
        Create a session
        """
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        config.allow_soft_placement = True
        config.log_device_placement = False
        sess = tf.Session(config=config)

        
        """
        Add summary writers
        merged = tf.merge_all_summaries()
        """
        merged = tf.summary.merge_all()

        train_writer_path = os.path.abspath( os.path.join(model_save_path, 'train') )
        if os.path.isdir(train_writer_path): os.system('rm -r {}'.format(train_writer_path))
        os.mkdir(train_writer_path)

        test_writer_path = os.path.abspath( os.path.join(model_save_path, 'test') )
        if os.path.isdir(test_writer_path): os.system('rm -r {}'.format(test_writer_path))
        os.mkdir(test_writer_path)


        train_writer = tf.summary.FileWriter(train_writer_path, sess.graph)
        test_writer = tf.summary.FileWriter(test_writer_path)

        
        """
        Init variables
        """
        init = tf.global_variables_initializer()
        # To fix the bug introduced in TF 0.12.1 as in
        # http://stackoverflow.com/questions/41543774/invalidargumenterror-for-tensor-bool-tensorflow-0-12-1
        #sess.run(init)
        sess.run(init, {is_training_pl: True})

        ops = {'pointclouds_pl': pointclouds_pl,
               'class_labels_pl': class_labels_pl,
               'heading_labels_pl': heading_labels_pl,
               'is_training_pl': is_training_pl,
               'pred': pred,
               'loss': loss,
               'classify_loss': classify_loss,
               'mat_diff_loss': mat_diff_loss,
               'heading_loss': heading_loss,
               'train_op': train_op,
               'merged': merged,
               'step': batch}


        for epoch in range(MAX_EPOCH):

            ## Training
            print "\n\n Train one epoch %3d / %3d" % (epoch+1, MAX_EPOCH)
            sys.stdout.flush()

            is_training = True

            
            """
            Shuffle train files
            """
            train_file_idxs = np.arange(0, data_train.shape[0])
            np.random.shuffle(train_file_idxs)

            current_data = data_train[train_file_idxs] 
            current_class_label = class_label_train[train_file_idxs]
            current_heading_label = heading_label_train[train_file_idxs]
            
            current_class_label.reshape((data_train.shape[0],))
            current_heading_label.reshape((data_train.shape[0],))

            
            """
            Evaluation metric
            """
            class_results = []
            heading_results = []
            

            """
            Run batch training
            """
            num_batches = current_data.shape[0] // BATCH_SIZE

            for batch_idx in trange(num_batches):

                start_idx = batch_idx * BATCH_SIZE
                end_idx = (batch_idx+1) * BATCH_SIZE           

                # Augment batched point clouds by rotation and jittering
                rotated_data = provider.rotate_point_cloud(current_data[start_idx:end_idx, :, :])
                jittered_data = provider.jitter_point_cloud(rotated_data)

                # Reashape
                current_class_label_reshape = current_class_label[start_idx:end_idx].reshape((BATCH_SIZE,))
                current_heading_label_reshape = current_heading_label[start_idx:end_idx].reshape((BATCH_SIZE,))

                feed_dict = {ops['pointclouds_pl']: jittered_data,
                             ops['class_labels_pl']: current_class_label_reshape,
                             ops['heading_labels_pl']: current_heading_label_reshape,
                             ops['is_training_pl']: is_training,}

                summary, step, _, loss_val,loss_cls,loss_mat,loss_hea, pred_val = sess.run([ops['merged'], 
                                                                 ops['step'],
                                                                 ops['train_op'], 
                                                                 ops['loss'], 
                                                                 ops['classify_loss'],
                                                                 ops['mat_diff_loss'],
                                                                 ops['heading_loss'],
                                                                 ops['pred']], feed_dict=feed_dict)

                train_writer.add_summary(summary, step)
                
                """
                Evaluation
                """
                # heading
                heading_results.extend(pred_val[:,3])
                # class
                pred_val_class = np.argmax(pred_val[:,:3], 1)
                class_results.extend(pred_val_class)
            
            """
            Results
            """
            ## Loss
            print "Total loss: {}".format(np.mean(loss_val))
            print "- cls loss: {}".format(np.mean(loss_cls))
            print "- mat loss: {}".format(np.mean(loss_mat))
            print "- heading loss: {}".format(np.mean(loss_hea))
            
            
            
            ## Classification
            prediction = np.array(class_results)
            ground_truth = np.array(current_class_label[:num_batches*BATCH_SIZE])
            cm = confusion_matrix(ground_truth, prediction)
            label_list = ['unknown', 'car', 'pedes']
            print(classification_report(ground_truth, prediction, target_names=label_list))
            
            ## Heading
            y_pred = np.asarray(heading_results)
            y_true = np.asarray(current_heading_label[:num_batches*BATCH_SIZE])
            y_pred = y_pred.reshape(y_true.shape)

            error = np.abs(y_true - y_pred)
            rmse = np.square( np.mean (error**2) )
        #     print('- Explained_variance_score: {}'.format(explained_variance_score(y_true, y_pred)))
        #     print('- R2_score: {}'.format(r2_score(y_true, y_pred)))
            print('- Root mean_squared_errors [deg]: {}'.format(rmse * 360.))
            plt.plot(y_true, label = 'truth')
            plt.plot(y_pred, label = 'prediction')
            plt.legend()
            plt.show()    
            
            """
            Evaluation using validation set    
            """
            
            print " Evaluation one (validation set) epoch %3d / %3d" % (epoch+1, MAX_EPOCH)
            sys.stdout.flush()

            is_training = False


            """
            Evaluation metric
            """
            class_results = []
            heading_results = []
                       
            
            """
            Shuffle validation files
            """
            file_idxs = np.arange(0, data_vali.shape[0])
            np.random.shuffle(file_idxs)

            current_data = data_vali[file_idxs]
            current_class_label = class_label_vali[file_idxs]
            current_heading_label = heading_label_vali[file_idxs]

            num_batches = current_data.shape[0] // BATCH_SIZE

            
            """
            Run batch validation
            """
            num_batches = current_data.shape[0] // BATCH_SIZE

            for batch_idx in trange(num_batches):

                start_idx = batch_idx * BATCH_SIZE
                end_idx = (batch_idx+1) * BATCH_SIZE

                
                """
                Reashape
                """
                current_class_label_reshape = current_class_label[start_idx:end_idx].reshape((BATCH_SIZE,))
                current_heading_label_reshape = current_heading_label[start_idx:end_idx].reshape((BATCH_SIZE,))

                
                """
                Feed dict
                """
                feed_dict = {ops['pointclouds_pl']: current_data[start_idx:end_idx, :, :],
                             ops['class_labels_pl']: current_class_label_reshape,
                             ops['heading_labels_pl']: current_heading_label_reshape,
                             ops['is_training_pl']: is_training}
                
                """
                Run session
                """
                summary, step, loss_val, loss_cls, loss_mat, loss_hea, pred_val = sess.run([ops['merged'], ops['step'],
                                                              ops['loss'], 
                                                              ops['classify_loss'], 
                                                              ops['mat_diff_loss'], 
                                                              ops['heading_loss'], 
                                                              ops['pred']], feed_dict=feed_dict)

                test_writer.add_summary(summary, step)

                """
                Evaluation
                """
                # heading
                heading_results.extend(pred_val[:,3])

                pred_val_class = np.argmax(pred_val[:,:3], 1)
                class_results.extend(pred_val_class)
            
            ## Loss
            print "Total loss: {}".format(np.mean(loss_val))
            print "- cls loss: {}".format(np.mean(loss_cls))
            print "- mat loss: {}".format(np.mean(loss_mat))
            print "- heading loss: {}".format(np.mean(loss_hea))
            
            
            ## Classification
            prediction = np.array(class_results)
            ground_truth = np.array(current_class_label[:num_batches*BATCH_SIZE])
            cm = confusion_matrix(ground_truth, prediction)
            label_list = ['unknown', 'car', 'pedes']
            print(classification_report(ground_truth, prediction, target_names=label_list))
            
            ## Heading
            y_pred = np.asarray(heading_results)
            y_true = np.asarray(current_heading_label[:num_batches*BATCH_SIZE])
            y_pred = y_pred.reshape(y_true.shape)

            error = np.abs(y_true - y_pred)
            rmse = np.square( np.mean (error**2) )
        #     print('- Explained_variance_score: {}'.format(explained_variance_score(y_true, y_pred)))
        #     print('- R2_score: {}'.format(r2_score(y_true, y_pred)))
            print('- Root mean_squared_errors [deg]: {}'.format(rmse * 360.))
            plt.plot(y_true, label = 'truth')
            plt.plot(y_pred, label = 'prediction')
            plt.legend()
            plt.show() 
                
            """
            Save the variables to disk.
            """
#             if ( epoch + 1 ) % 10 == 0:
            save_path = saver.save(sess, os.path.join(model_save_path, "model.ckpt"))
            print "Model saved in file: %s" % save_path

                
# option 1: execute code with extra process
p = multiprocessing.Process(target=run_training, args = ('./model_out_1',))
p.start()
p.join()
# Out:
# Tensor("Placeholder_3:0", shape=(), dtype=bool, device=/device:GPU:0)
#
#
#  Train one epoch   1 /  10
# 100%|██████████| 1615/1615 [09:38<00:00,  2.79it/s]
# Total loss: 1.63584566116
# - cls loss: 0.729047596455
# - mat loss: 2.08708620071
# - heading loss: 0.0904711037874
#              precision    recall  f1-score   support
#
#     unknown       0.69      0.64      0.67     35517
#         car       0.71      0.76      0.73     36234
#       pedes       0.82      0.82      0.82      8999
#
# avg / total       0.72      0.72      0.71     80750
#
# - Root mean_squared_errors [deg]: 2.83238254488
#  Evaluation one (validation set) epoch   1 /  10
# 100%|██████████| 538/538 [00:45<00:00, 11.84it/s]
# Total loss: 1.48332905769
# - cls loss: 0.67468637228
# - mat loss: 1.64805793762
# - heading loss: 0.0806994661689
#              precision    recall  f1-score   support
#
#     unknown       0.80      0.85      0.83     11804
#         car       0.86      0.83      0.84     12099
#       pedes       0.92      0.86      0.89      2997
#
# avg / total       0.84      0.84      0.84     26900
#
# - Root mean_squared_errors [deg]: 2.51457011327
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   2 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.80it/s]
# Total loss: 1.50479066372
# - cls loss: 0.654770791531
# - mat loss: 3.36858677864
# - heading loss: 0.0846651270986
#              precision    recall  f1-score   support
#
#     unknown       0.79      0.76      0.78     35517
#         car       0.80      0.83      0.82     36233
#       pedes       0.87      0.90      0.89      9000
#
# avg / total       0.81      0.81      0.81     80750
#
# - Root mean_squared_errors [deg]: 2.55736811087
#  Evaluation one (validation set) epoch   2 /  10
# 100%|██████████| 538/538 [00:44<00:00, 12.00it/s]
# Total loss: 1.45954704285
# - cls loss: 0.602944970131
# - mat loss: 3.79019451141
# - heading loss: 0.0852811858058
#              precision    recall  f1-score   support
#
#     unknown       0.85      0.89      0.87     11804
#         car       0.93      0.87      0.90     12100
#       pedes       0.85      0.90      0.88      2996
#
# avg / total       0.88      0.88      0.88     26900
#
# - Root mean_squared_errors [deg]: 2.49123036861
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   3 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 1.41750741005
# - cls loss: 0.589951395988
# - mat loss: 0.971715569496
# - heading loss: 0.0826584324241
#              precision    recall  f1-score   support
#
#     unknown       0.85      0.82      0.84     35518
#         car       0.86      0.88      0.87     36232
#       pedes       0.88      0.91      0.89      9000
#
# avg / total       0.86      0.86      0.86     80750
#
# - Root mean_squared_errors [deg]: 2.50162711367
#  Evaluation one (validation set) epoch   3 /  10
# 100%|██████████| 538/538 [00:44<00:00, 12.00it/s]
# Total loss: 1.3378880024
# - cls loss: 0.583506941795
# - mat loss: 1.02337193489
# - heading loss: 0.075335778296
#              precision    recall  f1-score   support
#
#     unknown       0.92      0.95      0.93     11804
#         car       0.97      0.94      0.95     12101
#       pedes       0.90      0.89      0.90      2995
#
# avg / total       0.94      0.94      0.94     26900
#
# - Root mean_squared_errors [deg]: 2.48437346891
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   4 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 1.42956256866
# - cls loss: 0.604762256145
# - mat loss: 0.90632724762
# - heading loss: 0.0823893994093
#              precision    recall  f1-score   support
#
#     unknown       0.89      0.88      0.88     35514
#         car       0.91      0.91      0.91     36237
#       pedes       0.88      0.92      0.90      8999
#
# avg / total       0.90      0.90      0.90     80750
#
# - Root mean_squared_errors [deg]: 2.50231057405
#  Evaluation one (validation set) epoch   4 /  10
# 100%|██████████| 538/538 [00:44<00:00, 12.00it/s]
# Total loss: 1.24720335007
# - cls loss: 0.561234891415
# - mat loss: 1.10255765915
# - heading loss: 0.0684865862131
#              precision    recall  f1-score   support
#
#     unknown       0.93      0.97      0.95     11806
#         car       0.98      0.96      0.97     12100
#       pedes       0.93      0.87      0.90      2994
#
# avg / total       0.95      0.95      0.95     26900
#
# - Root mean_squared_errors [deg]: 2.49314513057
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   5 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 1.28326272964
# - cls loss: 0.609243929386
# - mat loss: 0.937555134296
# - heading loss: 0.0673081278801
#              precision    recall  f1-score   support
#
#     unknown       0.91      0.90      0.90     35515
#         car       0.93      0.93      0.93     36235
#       pedes       0.89      0.92      0.91      9000
#
# avg / total       0.92      0.92      0.92     80750
#
# - Root mean_squared_errors [deg]: 2.50271525234
#  Evaluation one (validation set) epoch   5 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.98it/s]
# Total loss: 1.51585495472
# - cls loss: 0.57140737772
# - mat loss: 0.636644303799
# - heading loss: 0.0943810939789
#              precision    recall  f1-score   support
#
#     unknown       0.96      0.97      0.97     11803
#         car       0.99      0.98      0.99     12101
#       pedes       0.92      0.88      0.90      2996
#
# avg / total       0.97      0.97      0.97     26900
#
# - Root mean_squared_errors [deg]: 2.48739933595
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   6 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 1.38417410851
# - cls loss: 0.589816570282
# - mat loss: 1.07496738434
# - heading loss: 0.0793282613158
#              precision    recall  f1-score   support
#
#     unknown       0.93      0.93      0.93     35516
#         car       0.96      0.95      0.95     36238
#       pedes       0.89      0.93      0.91      8996
#
# avg / total       0.94      0.94      0.94     80750
#
# - Root mean_squared_errors [deg]: 2.49497624114
#  Evaluation one (validation set) epoch   6 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.99it/s]
# Total loss: 1.49097776413
# - cls loss: 0.573326528072
# - mat loss: 0.95253264904
# - heading loss: 0.0916698649526
#              precision    recall  f1-score   support
#
#     unknown       0.94      0.98      0.96     11799
#         car       1.00      0.96      0.98     12105
#       pedes       0.91      0.91      0.91      2996
#
# avg / total       0.96      0.96      0.96     26900
#
# - Root mean_squared_errors [deg]: 2.48418588191
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   7 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 1.33533155918
# - cls loss: 0.576379001141
# - mat loss: 0.405667364597
# - heading loss: 0.0758546888828
#              precision    recall  f1-score   support
#
#     unknown       0.94      0.94      0.94     35516
#         car       0.96      0.96      0.96     36235
#       pedes       0.90      0.94      0.92      8999
#
# avg / total       0.95      0.95      0.95     80750
#
# - Root mean_squared_errors [deg]: 2.4946109578
#  Evaluation one (validation set) epoch   7 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.99it/s]
# Total loss: 1.49321067333
# - cls loss: 0.583014309406
# - mat loss: 0.509567320347
# - heading loss: 0.090968683362
#              precision    recall  f1-score   support
#
#     unknown       0.92      0.98      0.95     11798
#         car       1.00      0.95      0.97     12108
#       pedes       0.93      0.88      0.90      2994
#
# avg / total       0.96      0.96      0.96     26900
#
# - Root mean_squared_errors [deg]: 2.48943714425
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   8 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 1.52355885506
# - cls loss: 0.579471647739
# - mat loss: 0.207719415426
# - heading loss: 0.0943879559636
#              precision    recall  f1-score   support
#
#     unknown       0.95      0.94      0.95     35514
#         car       0.97      0.96      0.97     36236
#       pedes       0.90      0.95      0.92      9000
#
# avg / total       0.95      0.95      0.95     80750
#
# - Root mean_squared_errors [deg]: 2.49292820692
#  Evaluation one (validation set) epoch   8 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.97it/s]
# Total loss: 1.17306780815
# - cls loss: 0.551557898521
# - mat loss: 0.267164319754
# - heading loss: 0.0621242746711
#              precision    recall  f1-score   support
#
#     unknown       0.96      0.98      0.97     11804
#         car       0.99      0.98      0.99     12098
#       pedes       0.92      0.90      0.91      2998
#
# avg / total       0.97      0.97      0.97     26900
#
# - Root mean_squared_errors [deg]: 2.48693481088
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   9 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 1.25774526596
# - cls loss: 0.600018024445
# - mat loss: 0.427919089794
# - heading loss: 0.0657299384475
#              precision    recall  f1-score   support
#
#     unknown       0.96      0.95      0.95     35514
#         car       0.98      0.97      0.97     36236
#       pedes       0.90      0.94      0.92      9000
#
# avg / total       0.96      0.96      0.96     80750
#
# - Root mean_squared_errors [deg]: 2.49085368589
#  Evaluation one (validation set) epoch   9 /  10
# 100%|██████████| 538/538 [00:44<00:00, 12.00it/s]
# Total loss: 1.38662934303
# - cls loss: 0.564455807209
# - mat loss: 0.333092302084
# - heading loss: 0.0821840390563
#              precision    recall  f1-score   support
#
#     unknown       0.97      0.98      0.97     11798
#         car       0.99      0.99      0.99     12106
#       pedes       0.93      0.90      0.91      2996
#
# avg / total       0.97      0.97      0.97     26900
#
# - Root mean_squared_errors [deg]: 2.48695123941
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch  10 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 1.35723435879
# - cls loss: 0.581375658512
# - mat loss: 0.745458543301
# - heading loss: 0.0775113254786
#              precision    recall  f1-score   support
#
#     unknown       0.96      0.95      0.96     35516
#         car       0.98      0.97      0.98     36235
#       pedes       0.91      0.95      0.93      8999
#
# avg / total       0.96      0.96      0.96     80750
#
# - Root mean_squared_errors [deg]: 2.48951559886
#  Evaluation one (validation set) epoch  10 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.98it/s]
# Total loss: 1.3969142437
# - cls loss: 0.573226153851
# - mat loss: 0.380753010511
# - heading loss: 0.0823307335377
#              precision    recall  f1-score   support
#
#     unknown       0.97      0.98      0.97     11805
#         car       0.99      0.99      0.99     12101
#       pedes       0.93      0.90      0.91      2994
#
# avg / total       0.97      0.97      0.97     26900
#
# - Root mean_squared_errors [deg]: 2.48965390027
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt

# %%
import os, sys

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import explained_variance_score, mean_squared_error, mean_absolute_error, r2_score

"""
Import model 
"""
sys.path.append( os.path.abspath('../../model') )

from train import *
import model_out_5_heading_3_relu as MODEL



def run_training(out_path):
    
    """ Path """
    model_save_path = os.path.abspath(out_path)
    if not os.path.isdir(model_save_path) : os.mkdir(model_save_path)
        
    """ Parameters """
    GPU_INDEX = 0
    NUM_POINT = 1024
    NUM_CLASSES = 3

    BN_INIT_DECAY = 0.5
    BN_DECAY_DECAY_RATE = 0.5
    BN_DECAY_DECAY_STEP = float(200000)
    BN_DECAY_CLIP = 0.99
    DECAY_STEP = BN_DECAY_DECAY_STEP
    DECAY_RATE = BN_DECAY_DECAY_RATE

    BATCH_SIZE = 50

    MOMENTUM = 0.9

    BASE_LEARNING_RATE = 0.001

    OPTIMIZER = 'adam'

    MAX_EPOCH = 10
    
    HEADING_LOSS_WEIGHT = 10.0


    
    def get_learning_rate(batch):
        learning_rate = tf.train.exponential_decay(
                            BASE_LEARNING_RATE,  # Base learning rate.
                            batch * BATCH_SIZE,  # Current index into the dataset.
                            DECAY_STEP,          # Decay step.
                            DECAY_RATE,          # Decay rate.
                            staircase=True)
        learning_rate = tf.maximum(learning_rate, 0.00001) # CLIP THE LEARNING RATE!
        return learning_rate        

    def get_bn_decay(batch):
        bn_momentum = tf.train.exponential_decay(
                          BN_INIT_DECAY,
                          batch * BATCH_SIZE,
                          BN_DECAY_DECAY_STEP,
                          BN_DECAY_DECAY_RATE,
                          staircase=True)
        bn_decay = tf.minimum(BN_DECAY_CLIP, 1 - bn_momentum)
        return bn_decay

    
    """
    load traing model
    """
    with tf.Graph().as_default():
        with tf.device('/gpu:'+str(GPU_INDEX)):
            
            
            """
            Placeholder
            """
            pointclouds_pl, class_labels_pl, heading_labels_pl = MODEL.placeholder_inputs(BATCH_SIZE, NUM_POINT)
            is_training_pl = tf.placeholder(tf.bool, shape=())
            print(is_training_pl)

            
            """
            decay
            """
            # Note the global_step=batch parameter to minimize. 
            # That tells the optimizer to helpfully increment the 'batch' parameter for you every time it trains.
            batch = tf.Variable(0)
            bn_decay = get_bn_decay(batch)
            tf.summary.scalar('bn_decay', bn_decay)
            
            
            """
            Get model and loss 
            """
            pred, end_points = MODEL.get_model(pointclouds_pl, is_training_pl, bn_decay=bn_decay)
            loss = MODEL.get_loss(pred, class_labels_pl, heading_labels_pl, end_points, h_reg_weight=HEADING_LOSS_WEIGHT)
            tf.summary.scalar('loss', loss)
            
            classify_loss = MODEL.get_classify_loss(pred, class_labels_pl)
            mat_diff_loss = MODEL.get_mat_diff_loss(end_points)
            heading_loss = MODEL.get_heading_loss(pred, heading_labels_pl)
            
            tf.summary.scalar('classify_loss', classify_loss)
            tf.summary.scalar('mat_diff_loss', mat_diff_loss)
            tf.summary.scalar('heading_loss', heading_loss)

            
            """
            Get accuracy 
            """
            correct = tf.equal(tf.argmax(tf.slice(pred, [0,0], [BATCH_SIZE,3]), 1), tf.to_int64(class_labels_pl))
            accuracy = tf.reduce_sum(tf.cast(correct, tf.float32)) / float(BATCH_SIZE)
            tf.summary.scalar('accuracy', accuracy)

            
            """
            Get training operator
            """
            learning_rate = get_learning_rate(batch)
            tf.summary.scalar('learning_rate', learning_rate)
            if OPTIMIZER == 'momentum':
                optimizer = tf.train.MomentumOptimizer(learning_rate, momentum=MOMENTUM)
            elif OPTIMIZER == 'adam':
                optimizer = tf.train.AdamOptimizer(learning_rate)
            train_op = optimizer.minimize(loss, global_step=batch)

            
            """
            Add ops to save and restore all the variables.
            """
            saver = tf.train.Saver()

            
        """
        Create a session
        """
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        config.allow_soft_placement = True
        config.log_device_placement = False
        sess = tf.Session(config=config)

        
        """
        Add summary writers
        merged = tf.merge_all_summaries()
        """
        merged = tf.summary.merge_all()

        train_writer_path = os.path.abspath( os.path.join(model_save_path, 'train') )
        if os.path.isdir(train_writer_path): os.system('rm -r {}'.format(train_writer_path))
        os.mkdir(train_writer_path)

        test_writer_path = os.path.abspath( os.path.join(model_save_path, 'test') )
        if os.path.isdir(test_writer_path): os.system('rm -r {}'.format(test_writer_path))
        os.mkdir(test_writer_path)


        train_writer = tf.summary.FileWriter(train_writer_path, sess.graph)
        test_writer = tf.summary.FileWriter(test_writer_path)

        
        """
        Init variables
        """
        init = tf.global_variables_initializer()
        # To fix the bug introduced in TF 0.12.1 as in
        # http://stackoverflow.com/questions/41543774/invalidargumenterror-for-tensor-bool-tensorflow-0-12-1
        #sess.run(init)
        sess.run(init, {is_training_pl: True})

        ops = {'pointclouds_pl': pointclouds_pl,
               'class_labels_pl': class_labels_pl,
               'heading_labels_pl': heading_labels_pl,
               'is_training_pl': is_training_pl,
               'pred': pred,
               'loss': loss,
               'classify_loss': classify_loss,
               'mat_diff_loss': mat_diff_loss,
               'heading_loss': heading_loss,
               'train_op': train_op,
               'merged': merged,
               'step': batch}


        for epoch in range(MAX_EPOCH):

            ## Training
            print "\n\n Train one epoch %3d / %3d" % (epoch+1, MAX_EPOCH)
            sys.stdout.flush()

            is_training = True

            
            """
            Shuffle train files
            """
            train_file_idxs = np.arange(0, data_train.shape[0])
            np.random.shuffle(train_file_idxs)

            current_data = data_train[train_file_idxs] 
            current_class_label = class_label_train[train_file_idxs]
            current_heading_label = heading_label_train[train_file_idxs]
            
            current_class_label.reshape((data_train.shape[0],))
            current_heading_label.reshape((data_train.shape[0],))

            
            """
            Evaluation metric
            """
            class_results = []
            heading_results = []
            

            """
            Run batch training
            """
            num_batches = current_data.shape[0] // BATCH_SIZE

            for batch_idx in trange(num_batches):

                start_idx = batch_idx * BATCH_SIZE
                end_idx = (batch_idx+1) * BATCH_SIZE           

                # Augment batched point clouds by rotation and jittering
                rotated_data = provider.rotate_point_cloud(current_data[start_idx:end_idx, :, :])
                jittered_data = provider.jitter_point_cloud(rotated_data)

                # Reashape
                current_class_label_reshape = current_class_label[start_idx:end_idx].reshape((BATCH_SIZE,))
                current_heading_label_reshape = current_heading_label[start_idx:end_idx].reshape((BATCH_SIZE,))

                feed_dict = {ops['pointclouds_pl']: jittered_data,
                             ops['class_labels_pl']: current_class_label_reshape,
                             ops['heading_labels_pl']: current_heading_label_reshape,
                             ops['is_training_pl']: is_training,}

                summary, step, _, loss_val,loss_cls,loss_mat,loss_hea, pred_val = sess.run([ops['merged'], 
                                                                 ops['step'],
                                                                 ops['train_op'], 
                                                                 ops['loss'], 
                                                                 ops['classify_loss'],
                                                                 ops['mat_diff_loss'],
                                                                 ops['heading_loss'],
                                                                 ops['pred']], feed_dict=feed_dict)

                train_writer.add_summary(summary, step)
                
                """
                Evaluation
                """
                # heading
                heading_results.extend(pred_val[:,3])
                # class
                pred_val_class = np.argmax(pred_val[:,:3], 1)
                class_results.extend(pred_val_class)
            
            """
            Results
            """
            ## Loss
            print "Total loss: {}".format(np.mean(loss_val))
            print "- cls loss: {}".format(np.mean(loss_cls))
            print "- mat loss: {}".format(np.mean(loss_mat))
            print "- heading loss: {}".format(np.mean(loss_hea))
            
            
            
            ## Classification
            prediction = np.array(class_results)
            ground_truth = np.array(current_class_label[:num_batches*BATCH_SIZE])
            cm = confusion_matrix(ground_truth, prediction)
            label_list = ['unknown', 'car', 'pedes']
            print(classification_report(ground_truth, prediction, target_names=label_list))
            
            ## Heading
            y_pred = np.asarray(heading_results)
            y_true = np.asarray(current_heading_label[:num_batches*BATCH_SIZE])
            y_pred = y_pred.reshape(y_true.shape)

            error = np.abs(y_true - y_pred)
            rmse = np.square( np.mean (error**2) )
        #     print('- Explained_variance_score: {}'.format(explained_variance_score(y_true, y_pred)))
        #     print('- R2_score: {}'.format(r2_score(y_true, y_pred)))
            print('- Root mean_squared_errors [deg]: {}'.format(rmse * 360.))
            plt.plot(y_true, label = 'truth')
            plt.plot(y_pred, label = 'prediction')
            plt.legend()
            plt.show()    
            
            """
            Evaluation using validation set    
            """
            
            print " Evaluation one (validation set) epoch %3d / %3d" % (epoch+1, MAX_EPOCH)
            sys.stdout.flush()

            is_training = False


            """
            Evaluation metric
            """
            class_results = []
            heading_results = []
                       
            
            """
            Shuffle validation files
            """
            file_idxs = np.arange(0, data_vali.shape[0])
            np.random.shuffle(file_idxs)

            current_data = data_vali[file_idxs]
            current_class_label = class_label_vali[file_idxs]
            current_heading_label = heading_label_vali[file_idxs]

            num_batches = current_data.shape[0] // BATCH_SIZE

            
            """
            Run batch validation
            """
            num_batches = current_data.shape[0] // BATCH_SIZE

            for batch_idx in trange(num_batches):

                start_idx = batch_idx * BATCH_SIZE
                end_idx = (batch_idx+1) * BATCH_SIZE

                
                """
                Reashape
                """
                current_class_label_reshape = current_class_label[start_idx:end_idx].reshape((BATCH_SIZE,))
                current_heading_label_reshape = current_heading_label[start_idx:end_idx].reshape((BATCH_SIZE,))

                
                """
                Feed dict
                """
                feed_dict = {ops['pointclouds_pl']: current_data[start_idx:end_idx, :, :],
                             ops['class_labels_pl']: current_class_label_reshape,
                             ops['heading_labels_pl']: current_heading_label_reshape,
                             ops['is_training_pl']: is_training}
                
                """
                Run session
                """
                summary, step, loss_val, loss_cls, loss_mat, loss_hea, pred_val = sess.run([ops['merged'], ops['step'],
                                                              ops['loss'], 
                                                              ops['classify_loss'], 
                                                              ops['mat_diff_loss'], 
                                                              ops['heading_loss'], 
                                                              ops['pred']], feed_dict=feed_dict)

                test_writer.add_summary(summary, step)

                """
                Evaluation
                """
                # heading
                heading_results.extend(pred_val[:,3])

                pred_val_class = np.argmax(pred_val[:,:3], 1)
                class_results.extend(pred_val_class)
            
            ## Loss
            print "Total loss: {}".format(np.mean(loss_val))
            print "- cls loss: {}".format(np.mean(loss_cls))
            print "- mat loss: {}".format(np.mean(loss_mat))
            print "- heading loss: {}".format(np.mean(loss_hea))
            
            
            ## Classification
            prediction = np.array(class_results)
            ground_truth = np.array(current_class_label[:num_batches*BATCH_SIZE])
            cm = confusion_matrix(ground_truth, prediction)
            label_list = ['unknown', 'car', 'pedes']
            print(classification_report(ground_truth, prediction, target_names=label_list))
            
            ## Heading
            y_pred = np.asarray(heading_results)
            y_true = np.asarray(current_heading_label[:num_batches*BATCH_SIZE])
            y_pred = y_pred.reshape(y_true.shape)

            error = np.abs(y_true - y_pred)
            rmse = np.square( np.mean (error**2) )
        #     print('- Explained_variance_score: {}'.format(explained_variance_score(y_true, y_pred)))
        #     print('- R2_score: {}'.format(r2_score(y_true, y_pred)))
            print('- Root mean_squared_errors [deg]: {}'.format(rmse * 360.))
            plt.plot(y_true, label = 'truth')
            plt.plot(y_pred, label = 'prediction')
            plt.legend()
            plt.show() 
                
            """
            Save the variables to disk.
            """
#             if ( epoch + 1 ) % 10 == 0:
            save_path = saver.save(sess, os.path.join(model_save_path, "model.ckpt"))
            print "Model saved in file: %s" % save_path

                
# option 1: execute code with extra process
p = multiprocessing.Process(target=run_training, args = ('./model_out_1',))
p.start()
p.join()
# Out:
# Tensor("Placeholder_3:0", shape=(), dtype=bool, device=/device:GPU:0)
#
#
#  Train one epoch   1 /  10
# 100%|██████████| 1615/1615 [09:38<00:00,  2.79it/s]
# Total loss: 1.49360942841
# - cls loss: 0.534380376339
# - mat loss: 14.7932443619
# - heading loss: 0.0944435819983
#              precision    recall  f1-score   support
#
#     unknown       0.56      0.54      0.55     35517
#         car       0.60      0.70      0.65     36234
#       pedes       0.79      0.40      0.53      8999
#
# avg / total       0.60      0.59      0.59     80750
#
# - Root mean_squared_errors [deg]: 4.14071515203
#  Evaluation one (validation set) epoch   1 /  10
# 100%|██████████| 538/538 [00:45<00:00, 11.74it/s]
# Total loss: 2.55113220215
# - cls loss: 0.632798850536
# - mat loss: 904.645446777
# - heading loss: 0.101368792355
#              precision    recall  f1-score   support
#
#     unknown       0.70      0.55      0.61     11804
#         car       0.65      0.81      0.72     12099
#       pedes       0.91      0.82      0.86      2997
#
# avg / total       0.70      0.69      0.69     26900
#
# - Root mean_squared_errors [deg]: 3.85131720454
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   2 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.80it/s]
# Total loss: 1.42393660545
# - cls loss: 0.569461464882
# - mat loss: 5.04393053055
# - heading loss: 0.0849431231618
#              precision    recall  f1-score   support
#
#     unknown       0.71      0.63      0.67     35517
#         car       0.71      0.78      0.74     36233
#       pedes       0.83      0.85      0.84      9000
#
# avg / total       0.72      0.72      0.72     80750
#
# - Root mean_squared_errors [deg]: 3.0811631307
#  Evaluation one (validation set) epoch   2 /  10
# 100%|██████████| 538/538 [00:45<00:00, 11.77it/s]
# Total loss: 1.21776068211
# - cls loss: 0.345517039299
# - mat loss: 1.55724167824
# - heading loss: 0.0870686396956
#              precision    recall  f1-score   support
#
#     unknown       0.90      0.69      0.78     11804
#         car       0.76      0.96      0.85     12100
#       pedes       0.94      0.80      0.86      2996
#
# avg / total       0.84      0.82      0.82     26900
#
# - Root mean_squared_errors [deg]: 2.61244526133
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   3 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 1.21546268463
# - cls loss: 0.344968259335
# - mat loss: 6.36170339584
# - heading loss: 0.0864132717252
#              precision    recall  f1-score   support
#
#     unknown       0.80      0.75      0.77     35518
#         car       0.80      0.84      0.82     36232
#       pedes       0.87      0.90      0.88      9000
#
# avg / total       0.81      0.81      0.80     80750
#
# - Root mean_squared_errors [deg]: 2.89132341743
#  Evaluation one (validation set) epoch   3 /  10
# 100%|██████████| 538/538 [00:45<00:00, 11.77it/s]
# Total loss: 1.01719212532
# - cls loss: 0.249012470245
# - mat loss: 3.4681186676
# - heading loss: 0.076471157372
#              precision    recall  f1-score   support
#
#     unknown       0.93      0.83      0.88     11804
#         car       0.87      0.97      0.92     12101
#       pedes       0.93      0.87      0.90      2995
#
# avg / total       0.90      0.90      0.90     26900
#
# - Root mean_squared_errors [deg]: 2.49444935471
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   4 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.80it/s]
# Total loss: 1.11848556995
# - cls loss: 0.238823741674
# - mat loss: 6.48959493637
# - heading loss: 0.0873172283173
#              precision    recall  f1-score   support
#
#     unknown       0.87      0.87      0.87     35514
#         car       0.90      0.89      0.90     36237
#       pedes       0.87      0.92      0.89      8999
#
# avg / total       0.88      0.88      0.88     80750
#
# - Root mean_squared_errors [deg]: 2.91651774198
#  Evaluation one (validation set) epoch   4 /  10
# 100%|██████████| 538/538 [00:45<00:00, 11.93it/s]
# Total loss: 0.715917646885
# - cls loss: 0.028309488669
# - mat loss: 2.32346582413
# - heading loss: 0.0685284659266
#              precision    recall  f1-score   support
#
#     unknown       0.97      0.97      0.97     11806
#         car       0.99      1.00      0.99     12100
#       pedes       0.91      0.90      0.91      2994
#
# avg / total       0.97      0.97      0.97     26900
#
# - Root mean_squared_errors [deg]: 2.50630287454
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   5 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.80it/s]
# Total loss: 0.858953654766
# - cls loss: 0.0958696752787
# - mat loss: 6.62027215958
# - heading loss: 0.0756463706493
#              precision    recall  f1-score   support
#
#     unknown       0.91      0.91      0.91     35515
#         car       0.94      0.92      0.93     36235
#       pedes       0.89      0.94      0.91      9000
#
# avg / total       0.92      0.92      0.92     80750
#
# - Root mean_squared_errors [deg]: 2.94943448156
#  Evaluation one (validation set) epoch   5 /  10
# 100%|██████████| 538/538 [00:45<00:00, 11.94it/s]
# Total loss: 0.995889544487
# - cls loss: 0.048468388617
# - mat loss: 2.71429109573
# - heading loss: 0.0944706872106
#              precision    recall  f1-score   support
#
#     unknown       0.97      0.97      0.97     11803
#         car       0.99      0.99      0.99     12101
#       pedes       0.91      0.90      0.90      2996
#
# avg / total       0.97      0.97      0.97     26900
#
# - Root mean_squared_errors [deg]: 2.4930549413
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   6 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.79it/s]
# Total loss: 1.05185294151
# - cls loss: 0.203662455082
# - mat loss: 8.41635894775
# - heading loss: 0.0839774087071
#              precision    recall  f1-score   support
#
#     unknown       0.92      0.93      0.93     35516
#         car       0.96      0.93      0.95     36238
#       pedes       0.90      0.95      0.92      8996
#
# avg / total       0.94      0.93      0.93     80750
#
# - Root mean_squared_errors [deg]: 2.95494005084
#  Evaluation one (validation set) epoch   6 /  10
# 100%|██████████| 538/538 [00:45<00:00, 11.94it/s]
# Total loss: 0.991237819195
# - cls loss: 0.0734137073159
# - mat loss: 2.19639229774
# - heading loss: 0.0915627703071
#              precision    recall  f1-score   support
#
#     unknown       0.96      0.98      0.97     11799
#         car       0.99      0.97      0.98     12105
#       pedes       0.91      0.91      0.91      2996
#
# avg / total       0.97      0.97      0.97     26900
#
# - Root mean_squared_errors [deg]: 2.48592412099
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   7 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.79it/s]
# Total loss: 0.891544282436
# - cls loss: 0.0812988504767
# - mat loss: 5.28462696075
# - heading loss: 0.0804960802197
#              precision    recall  f1-score   support
#
#     unknown       0.94      0.94      0.94     35516
#         car       0.97      0.95      0.96     36235
#       pedes       0.92      0.96      0.94      8999
#
# avg / total       0.95      0.95      0.95     80750
#
# - Root mean_squared_errors [deg]: 2.92012464255
#  Evaluation one (validation set) epoch   7 /  10
# 100%|██████████| 538/538 [00:45<00:00, 11.95it/s]
# Total loss: 0.955027580261
# - cls loss: 0.0373587869108
# - mat loss: 1.23004603386
# - heading loss: 0.0916438773274
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.98      0.98     11798
#         car       0.99      0.99      0.99     12108
#       pedes       0.92      0.90      0.91      2994
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.48499875888
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   8 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.79it/s]
# Total loss: 1.14017236233
# - cls loss: 0.145336791873
# - mat loss: 2.87622261047
# - heading loss: 0.0991959348321
#              precision    recall  f1-score   support
#
#     unknown       0.94      0.96      0.95     35514
#         car       0.97      0.95      0.96     36236
#       pedes       0.93      0.96      0.95      9000
#
# avg / total       0.95      0.95      0.95     80750
#
# - Root mean_squared_errors [deg]: 2.91835974902
#  Evaluation one (validation set) epoch   8 /  10
# 100%|██████████| 538/538 [00:45<00:00, 11.92it/s]
# Total loss: 0.622531473637
# - cls loss: 0.00208325241692
# - mat loss: 1.31548380852
# - heading loss: 0.0619132742286
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.98      0.98     11804
#         car       0.99      0.99      0.99     12098
#       pedes       0.91      0.90      0.90      2998
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.48795153573
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   9 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.80it/s]
# Total loss: 0.837469816208
# - cls loss: 0.125059947371
# - mat loss: 4.30999279022
# - heading loss: 0.070809982717
#              precision    recall  f1-score   support
#
#     unknown       0.95      0.97      0.96     35514
#         car       0.98      0.96      0.97     36236
#       pedes       0.94      0.97      0.95      9000
#
# avg / total       0.96      0.96      0.96     80750
#
# - Root mean_squared_errors [deg]: 2.9334770143
#  Evaluation one (validation set) epoch   9 /  10
# 100%|██████████| 538/538 [00:45<00:00, 11.94it/s]
# Total loss: 0.834698438644
# - cls loss: 0.0109793320298
# - mat loss: 0.975812077522
# - heading loss: 0.0822743326426
#              precision    recall  f1-score   support
#
#     unknown       0.97      0.99      0.98     11798
#         car       0.99      0.99      0.99     12106
#       pedes       0.96      0.88      0.92      2996
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.48570082709
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch  10 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.80it/s]
# Total loss: 0.890254974365
# - cls loss: 0.0533549487591
# - mat loss: 1.31548190117
# - heading loss: 0.0835584551096
#              precision    recall  f1-score   support
#
#     unknown       0.96      0.97      0.96     35516
#         car       0.98      0.96      0.97     36235
#       pedes       0.95      0.97      0.96      8999
#
# avg / total       0.97      0.97      0.97     80750
#
# - Root mean_squared_errors [deg]: 2.9141580686
#  Evaluation one (validation set) epoch  10 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.97it/s]
# Total loss: 1.002145648
# - cls loss: 0.177408218384
# - mat loss: 0.997980237007
# - heading loss: 0.0823739469051
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.98      0.98     11805
#         car       0.99      1.00      0.99     12101
#       pedes       0.92      0.91      0.92      2994
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.48487219214
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt

# %%
import os, sys

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import explained_variance_score, mean_squared_error, mean_absolute_error, r2_score

"""
Import model 
"""
sys.path.append( os.path.abspath('../../model') )

from train import *
import model_out_5_heading_3_relu as MODEL



def run_training(out_path):
    
    """ Path """
    model_save_path = os.path.abspath(out_path)
    if not os.path.isdir(model_save_path) : os.mkdir(model_save_path)
        
    """ Parameters """
    GPU_INDEX = 0
    NUM_POINT = 1024
    NUM_CLASSES = 3

    BN_INIT_DECAY = 0.5
    BN_DECAY_DECAY_RATE = 0.5
    BN_DECAY_DECAY_STEP = float(200000)
    BN_DECAY_CLIP = 0.99
    DECAY_STEP = BN_DECAY_DECAY_STEP
    DECAY_RATE = BN_DECAY_DECAY_RATE

    BATCH_SIZE = 50

    MOMENTUM = 0.9

    BASE_LEARNING_RATE = 0.001

    OPTIMIZER = 'adam'

    MAX_EPOCH = 10
    
    HEADING_LOSS_WEIGHT = 1.0


    
    def get_learning_rate(batch):
        learning_rate = tf.train.exponential_decay(
                            BASE_LEARNING_RATE,  # Base learning rate.
                            batch * BATCH_SIZE,  # Current index into the dataset.
                            DECAY_STEP,          # Decay step.
                            DECAY_RATE,          # Decay rate.
                            staircase=True)
        learning_rate = tf.maximum(learning_rate, 0.00001) # CLIP THE LEARNING RATE!
        return learning_rate        

    def get_bn_decay(batch):
        bn_momentum = tf.train.exponential_decay(
                          BN_INIT_DECAY,
                          batch * BATCH_SIZE,
                          BN_DECAY_DECAY_STEP,
                          BN_DECAY_DECAY_RATE,
                          staircase=True)
        bn_decay = tf.minimum(BN_DECAY_CLIP, 1 - bn_momentum)
        return bn_decay

    
    """
    load traing model
    """
    with tf.Graph().as_default():
        with tf.device('/gpu:'+str(GPU_INDEX)):
            
            
            """
            Placeholder
            """
            pointclouds_pl, class_labels_pl, heading_labels_pl = MODEL.placeholder_inputs(BATCH_SIZE, NUM_POINT)
            is_training_pl = tf.placeholder(tf.bool, shape=())
            print(is_training_pl)

            
            """
            decay
            """
            # Note the global_step=batch parameter to minimize. 
            # That tells the optimizer to helpfully increment the 'batch' parameter for you every time it trains.
            batch = tf.Variable(0)
            bn_decay = get_bn_decay(batch)
            tf.summary.scalar('bn_decay', bn_decay)
            
            
            """
            Get model and loss 
            """
            pred, end_points = MODEL.get_model(pointclouds_pl, is_training_pl, bn_decay=bn_decay)
            loss = MODEL.get_loss(pred, class_labels_pl, heading_labels_pl, end_points, h_reg_weight=HEADING_LOSS_WEIGHT)
            tf.summary.scalar('loss', loss)
            
            classify_loss = MODEL.get_classify_loss(pred, class_labels_pl)
            mat_diff_loss = MODEL.get_mat_diff_loss(end_points)
            heading_loss = MODEL.get_heading_loss(pred, heading_labels_pl)
            
            tf.summary.scalar('classify_loss', classify_loss)
            tf.summary.scalar('mat_diff_loss', mat_diff_loss)
            tf.summary.scalar('heading_loss', heading_loss)

            
            """
            Get accuracy 
            """
            correct = tf.equal(tf.argmax(tf.slice(pred, [0,0], [BATCH_SIZE,3]), 1), tf.to_int64(class_labels_pl))
            accuracy = tf.reduce_sum(tf.cast(correct, tf.float32)) / float(BATCH_SIZE)
            tf.summary.scalar('accuracy', accuracy)

            
            """
            Get training operator
            """
            learning_rate = get_learning_rate(batch)
            tf.summary.scalar('learning_rate', learning_rate)
            if OPTIMIZER == 'momentum':
                optimizer = tf.train.MomentumOptimizer(learning_rate, momentum=MOMENTUM)
            elif OPTIMIZER == 'adam':
                optimizer = tf.train.AdamOptimizer(learning_rate)
            train_op = optimizer.minimize(loss, global_step=batch)

            
            """
            Add ops to save and restore all the variables.
            """
            saver = tf.train.Saver()

            
        """
        Create a session
        """
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        config.allow_soft_placement = True
        config.log_device_placement = False
        sess = tf.Session(config=config)

        
        """
        Add summary writers
        merged = tf.merge_all_summaries()
        """
        merged = tf.summary.merge_all()

        train_writer_path = os.path.abspath( os.path.join(model_save_path, 'train') )
        if os.path.isdir(train_writer_path): os.system('rm -r {}'.format(train_writer_path))
        os.mkdir(train_writer_path)

        test_writer_path = os.path.abspath( os.path.join(model_save_path, 'test') )
        if os.path.isdir(test_writer_path): os.system('rm -r {}'.format(test_writer_path))
        os.mkdir(test_writer_path)


        train_writer = tf.summary.FileWriter(train_writer_path, sess.graph)
        test_writer = tf.summary.FileWriter(test_writer_path)

        
        """
        Init variables
        """
        init = tf.global_variables_initializer()
        # To fix the bug introduced in TF 0.12.1 as in
        # http://stackoverflow.com/questions/41543774/invalidargumenterror-for-tensor-bool-tensorflow-0-12-1
        #sess.run(init)
        sess.run(init, {is_training_pl: True})

        ops = {'pointclouds_pl': pointclouds_pl,
               'class_labels_pl': class_labels_pl,
               'heading_labels_pl': heading_labels_pl,
               'is_training_pl': is_training_pl,
               'pred': pred,
               'loss': loss,
               'classify_loss': classify_loss,
               'mat_diff_loss': mat_diff_loss,
               'heading_loss': heading_loss,
               'train_op': train_op,
               'merged': merged,
               'step': batch}


        for epoch in range(MAX_EPOCH):

            ## Training
            print "\n\n Train one epoch %3d / %3d" % (epoch+1, MAX_EPOCH)
            sys.stdout.flush()

            is_training = True

            
            """
            Shuffle train files
            """
            train_file_idxs = np.arange(0, data_train.shape[0])
            np.random.shuffle(train_file_idxs)

            current_data = data_train[train_file_idxs] 
            current_class_label = class_label_train[train_file_idxs]
            current_heading_label = heading_label_train[train_file_idxs]
            
            current_class_label.reshape((data_train.shape[0],))
            current_heading_label.reshape((data_train.shape[0],))

            
            """
            Evaluation metric
            """
            class_results = []
            heading_results = []
            

            """
            Run batch training
            """
            num_batches = current_data.shape[0] // BATCH_SIZE

            for batch_idx in trange(num_batches):

                start_idx = batch_idx * BATCH_SIZE
                end_idx = (batch_idx+1) * BATCH_SIZE           

                # Augment batched point clouds by rotation and jittering
                rotated_data = provider.rotate_point_cloud(current_data[start_idx:end_idx, :, :])
                jittered_data = provider.jitter_point_cloud(rotated_data)

                # Reashape
                current_class_label_reshape = current_class_label[start_idx:end_idx].reshape((BATCH_SIZE,))
                current_heading_label_reshape = current_heading_label[start_idx:end_idx].reshape((BATCH_SIZE,))

                feed_dict = {ops['pointclouds_pl']: jittered_data,
                             ops['class_labels_pl']: current_class_label_reshape,
                             ops['heading_labels_pl']: current_heading_label_reshape,
                             ops['is_training_pl']: is_training,}

                summary, step, _, loss_val,loss_cls,loss_mat,loss_hea, pred_val = sess.run([ops['merged'], 
                                                                 ops['step'],
                                                                 ops['train_op'], 
                                                                 ops['loss'], 
                                                                 ops['classify_loss'],
                                                                 ops['mat_diff_loss'],
                                                                 ops['heading_loss'],
                                                                 ops['pred']], feed_dict=feed_dict)

                train_writer.add_summary(summary, step)
                
                """
                Evaluation
                """
                # heading
                heading_results.extend(pred_val[:,3])
                # class
                pred_val_class = np.argmax(pred_val[:,:3], 1)
                class_results.extend(pred_val_class)
            
            """
            Results
            """
            ## Loss
            print "Total loss: {}".format(np.mean(loss_val))
            print "- cls loss: {}".format(np.mean(loss_cls))
            print "- mat loss: {}".format(np.mean(loss_mat))
            print "- heading loss: {}".format(np.mean(loss_hea))
            
            
            
            ## Classification
            prediction = np.array(class_results)
            ground_truth = np.array(current_class_label[:num_batches*BATCH_SIZE])
            cm = confusion_matrix(ground_truth, prediction)
            label_list = ['unknown', 'car', 'pedes']
            print(classification_report(ground_truth, prediction, target_names=label_list))
            
            ## Heading
            y_pred = np.asarray(heading_results)
            y_true = np.asarray(current_heading_label[:num_batches*BATCH_SIZE])
            y_pred = y_pred.reshape(y_true.shape)

            error = np.abs(y_true - y_pred)
            rmse = np.square( np.mean (error**2) )
        #     print('- Explained_variance_score: {}'.format(explained_variance_score(y_true, y_pred)))
        #     print('- R2_score: {}'.format(r2_score(y_true, y_pred)))
            print('- Root mean_squared_errors [deg]: {}'.format(rmse * 360.))
            plt.plot(y_true, label = 'truth')
            plt.plot(y_pred, label = 'prediction')
            plt.legend()
            plt.show()    
            
            """
            Evaluation using validation set    
            """
            
            print " Evaluation one (validation set) epoch %3d / %3d" % (epoch+1, MAX_EPOCH)
            sys.stdout.flush()

            is_training = False


            """
            Evaluation metric
            """
            class_results = []
            heading_results = []
                       
            
            """
            Shuffle validation files
            """
            file_idxs = np.arange(0, data_vali.shape[0])
            np.random.shuffle(file_idxs)

            current_data = data_vali[file_idxs]
            current_class_label = class_label_vali[file_idxs]
            current_heading_label = heading_label_vali[file_idxs]

            num_batches = current_data.shape[0] // BATCH_SIZE

            
            """
            Run batch validation
            """
            num_batches = current_data.shape[0] // BATCH_SIZE

            for batch_idx in trange(num_batches):

                start_idx = batch_idx * BATCH_SIZE
                end_idx = (batch_idx+1) * BATCH_SIZE

                
                """
                Reashape
                """
                current_class_label_reshape = current_class_label[start_idx:end_idx].reshape((BATCH_SIZE,))
                current_heading_label_reshape = current_heading_label[start_idx:end_idx].reshape((BATCH_SIZE,))

                
                """
                Feed dict
                """
                feed_dict = {ops['pointclouds_pl']: current_data[start_idx:end_idx, :, :],
                             ops['class_labels_pl']: current_class_label_reshape,
                             ops['heading_labels_pl']: current_heading_label_reshape,
                             ops['is_training_pl']: is_training}
                
                """
                Run session
                """
                summary, step, loss_val, loss_cls, loss_mat, loss_hea, pred_val = sess.run([ops['merged'], ops['step'],
                                                              ops['loss'], 
                                                              ops['classify_loss'], 
                                                              ops['mat_diff_loss'], 
                                                              ops['heading_loss'], 
                                                              ops['pred']], feed_dict=feed_dict)

                test_writer.add_summary(summary, step)

                """
                Evaluation
                """
                # heading
                heading_results.extend(pred_val[:,3])

                pred_val_class = np.argmax(pred_val[:,:3], 1)
                class_results.extend(pred_val_class)
            
            ## Loss
            print "Total loss: {}".format(np.mean(loss_val))
            print "- cls loss: {}".format(np.mean(loss_cls))
            print "- mat loss: {}".format(np.mean(loss_mat))
            print "- heading loss: {}".format(np.mean(loss_hea))
            
            
            ## Classification
            prediction = np.array(class_results)
            ground_truth = np.array(current_class_label[:num_batches*BATCH_SIZE])
            cm = confusion_matrix(ground_truth, prediction)
            label_list = ['unknown', 'car', 'pedes']
            print(classification_report(ground_truth, prediction, target_names=label_list))
            
            ## Heading
            y_pred = np.asarray(heading_results)
            y_true = np.asarray(current_heading_label[:num_batches*BATCH_SIZE])
            y_pred = y_pred.reshape(y_true.shape)

            error = np.abs(y_true - y_pred)
            rmse = np.square( np.mean (error**2) )
        #     print('- Explained_variance_score: {}'.format(explained_variance_score(y_true, y_pred)))
        #     print('- R2_score: {}'.format(r2_score(y_true, y_pred)))
            print('- Root mean_squared_errors [deg]: {}'.format(rmse * 360.))
            plt.plot(y_true, label = 'truth')
            plt.plot(y_pred, label = 'prediction')
            plt.legend()
            plt.show() 
                
            """
            Save the variables to disk.
            """
#             if ( epoch + 1 ) % 10 == 0:
            save_path = saver.save(sess, os.path.join(model_save_path, "model.ckpt"))
            print "Model saved in file: %s" % save_path

                
# option 1: execute code with extra process
p = multiprocessing.Process(target=run_training, args = ('./model_out_1',))
p.start()
p.join()
# Out:
# Tensor("Placeholder_3:0", shape=(), dtype=bool, device=/device:GPU:0)
#
#
#  Train one epoch   1 /  10
# 100%|██████████| 1615/1615 [09:38<00:00,  2.79it/s]
# Total loss: 0.437517553568
# - cls loss: 0.331240355968
# - mat loss: 8.75881576538
# - heading loss: 0.0975183844566
#              precision    recall  f1-score   support
#
#     unknown       0.72      0.67      0.69     35517
#         car       0.73      0.79      0.76     36234
#       pedes       0.82      0.75      0.79      8999
#
# avg / total       0.74      0.74      0.73     80750
#
# - Root mean_squared_errors [deg]: 4.51492521912
#  Evaluation one (validation set) epoch   1 /  10
# 100%|██████████| 538/538 [00:45<00:00, 11.94it/s]
# Total loss: 0.416630744934
# - cls loss: 0.329946428537
# - mat loss: 5.87016677856
# - heading loss: 0.0808141604066
#              precision    recall  f1-score   support
#
#     unknown       0.79      0.88      0.83     11804
#         car       0.88      0.82      0.85     12099
#       pedes       0.93      0.82      0.87      2997
#
# avg / total       0.85      0.84      0.84     26900
#
# - Root mean_squared_errors [deg]: 2.50100065023
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   2 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 0.314490735531
# - cls loss: 0.204631388187
# - mat loss: 5.58643770218
# - heading loss: 0.104272887111
#              precision    recall  f1-score   support
#
#     unknown       0.85      0.84      0.84     35517
#         car       0.87      0.87      0.87     36233
#       pedes       0.87      0.91      0.89      9000
#
# avg / total       0.86      0.86      0.86     80750
#
# - Root mean_squared_errors [deg]: 3.01764775068
#  Evaluation one (validation set) epoch   2 /  10
# 100%|██████████| 538/538 [00:44<00:00, 12.01it/s]
# Total loss: 0.113166749477
# - cls loss: 0.0216907020658
# - mat loss: 5.31572151184
# - heading loss: 0.0861603245139
#              precision    recall  f1-score   support
#
#     unknown       0.94      0.96      0.95     11804
#         car       0.99      0.96      0.98     12100
#       pedes       0.87      0.91      0.89      2996
#
# avg / total       0.96      0.96      0.96     26900
#
# - Root mean_squared_errors [deg]: 2.5146750547
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   3 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.80it/s]
# Total loss: 0.245193213224
# - cls loss: 0.159199520946
# - mat loss: 1.39257955551
# - heading loss: 0.0846011266112
#              precision    recall  f1-score   support
#
#     unknown       0.91      0.91      0.91     35518
#         car       0.94      0.93      0.94     36232
#       pedes       0.88      0.93      0.91      9000
#
# avg / total       0.92      0.92      0.92     80750
#
# - Root mean_squared_errors [deg]: 2.82614640892
#  Evaluation one (validation set) epoch   3 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.99it/s]
# Total loss: 0.0865475535393
# - cls loss: 0.0117453709245
# - mat loss: 1.61299300194
# - heading loss: 0.0731891915202
#              precision    recall  f1-score   support
#
#     unknown       0.97      0.97      0.97     11804
#         car       0.99      0.99      0.99     12101
#       pedes       0.91      0.90      0.90      2995
#
# avg / total       0.97      0.97      0.97     26900
#
# - Root mean_squared_errors [deg]: 2.49763363972
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   4 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.80it/s]
# Total loss: 0.16946297884
# - cls loss: 0.084294013679
# - mat loss: 2.15417981148
# - heading loss: 0.083014793694
#              precision    recall  f1-score   support
#
#     unknown       0.95      0.94      0.94     35514
#         car       0.97      0.96      0.97     36237
#       pedes       0.89      0.94      0.92      8999
#
# avg / total       0.95      0.95      0.95     80750
#
# - Root mean_squared_errors [deg]: 2.5516124256
#  Evaluation one (validation set) epoch   4 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.98it/s]
# Total loss: 0.0869332700968
# - cls loss: 0.0167108476162
# - mat loss: 1.62319231033
# - heading loss: 0.0685992315412
#              precision    recall  f1-score   support
#
#     unknown       0.97      0.98      0.97     11806
#         car       0.99      0.99      0.99     12100
#       pedes       0.93      0.90      0.91      2994
#
# avg / total       0.97      0.97      0.97     26900
#
# - Root mean_squared_errors [deg]: 2.49847417697
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   5 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.80it/s]
# Total loss: 0.138080835342
# - cls loss: 0.0695413947105
# - mat loss: 1.16003704071
# - heading loss: 0.0673794001341
#              precision    recall  f1-score   support
#
#     unknown       0.97      0.96      0.96     35515
#         car       0.98      0.98      0.98     36235
#       pedes       0.90      0.96      0.93      9000
#
# avg / total       0.97      0.97      0.97     80750
#
# - Root mean_squared_errors [deg]: 2.54260774702
#  Evaluation one (validation set) epoch   5 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.98it/s]
# Total loss: 0.131440848112
# - cls loss: 0.035703189671
# - mat loss: 1.40576243401
# - heading loss: 0.0943318903446
#              precision    recall  f1-score   support
#
#     unknown       0.97      0.99      0.98     11803
#         car       0.99      0.99      0.99     12101
#       pedes       0.94      0.89      0.92      2996
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.48074460775
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   6 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.79it/s]
# Total loss: 0.107920616865
# - cls loss: 0.0270609315485
# - mat loss: 1.37092638016
# - heading loss: 0.079488761723
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.97      0.97     35516
#         car       0.99      0.99      0.99     36238
#       pedes       0.92      0.96      0.94      8996
#
# avg / total       0.98      0.98      0.98     80750
#
# - Root mean_squared_errors [deg]: 2.52111906186
#  Evaluation one (validation set) epoch   6 /  10
# 100%|██████████| 538/538 [00:44<00:00, 12.02it/s]
# Total loss: 0.125235810876
# - cls loss: 0.0323632359505
# - mat loss: 1.21665263176
# - heading loss: 0.0916559249163
#              precision    recall  f1-score   support
#
#     unknown       0.97      0.98      0.98     11799
#         car       0.99      0.99      0.99     12105
#       pedes       0.94      0.90      0.92      2996
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.48337887228
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   7 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.80it/s]
# Total loss: 0.0898720473051
# - cls loss: 0.012519848533
# - mat loss: 1.87489938736
# - heading loss: 0.0754773020744
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.98      0.98     35516
#         car       0.99      0.99      0.99     36235
#       pedes       0.93      0.97      0.95      8999
#
# avg / total       0.98      0.98      0.98     80750
#
# - Root mean_squared_errors [deg]: 2.51834062859
#  Evaluation one (validation set) epoch   7 /  10
# 100%|██████████| 538/538 [00:44<00:00, 12.01it/s]
# Total loss: 0.118486054242
# - cls loss: 0.0251240897924
# - mat loss: 1.1928589344
# - heading loss: 0.0921691060066
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.98      0.98     11798
#         car       0.99      1.00      0.99     12108
#       pedes       0.94      0.90      0.92      2994
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.48597625643
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   8 /  10
# 100%|██████████| 1615/1615 [09:38<00:00,  2.79it/s]
# Total loss: 0.101964659989
# - cls loss: 0.00606127921492
# - mat loss: 1.35173559189
# - heading loss: 0.0945516452193
#              precision    recall  f1-score   support
#
#     unknown       0.99      0.98      0.98     35514
#         car       0.99      0.99      0.99     36236
#       pedes       0.94      0.98      0.96      9000
#
# avg / total       0.99      0.99      0.99     80750
#
# - Root mean_squared_errors [deg]: 2.50970659778
#  Evaluation one (validation set) epoch   8 /  10
# 100%|██████████| 538/538 [00:44<00:00, 12.01it/s]
# Total loss: 0.0634616836905
# - cls loss: 0.000720263691619
# - mat loss: 1.11357784271
# - heading loss: 0.0616278424859
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.99      0.99     11804
#         car       0.99      1.00      0.99     12098
#       pedes       0.96      0.91      0.93      2998
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.49247457832
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   9 /  10
# 100%|██████████| 1615/1615 [09:38<00:00,  2.79it/s]
# Total loss: 0.0724243372679
# - cls loss: 0.00623598555103
# - mat loss: 1.38123321533
# - heading loss: 0.0648071169853
#              precision    recall  f1-score   support
#
#     unknown       0.99      0.98      0.99     35514
#         car       1.00      1.00      1.00     36236
#       pedes       0.96      0.98      0.97      9000
#
# avg / total       0.99      0.99      0.99     80750
#
# - Root mean_squared_errors [deg]: 2.51010658219
#  Evaluation one (validation set) epoch   9 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.98it/s]
# Total loss: 0.0931106954813
# - cls loss: 0.00829520728439
# - mat loss: 0.808866679668
# - heading loss: 0.0840066224337
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.99      0.98     11798
#         car       0.99      0.99      0.99     12106
#       pedes       0.97      0.89      0.93      2996
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.50902548432
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch  10 /  10
# 100%|██████████| 1615/1615 [09:37<00:00,  2.80it/s]
# Total loss: 0.0995351746678
# - cls loss: 0.0203749854118
# - mat loss: 1.64210832119
# - heading loss: 0.0775180831552
#              precision    recall  f1-score   support
#
#     unknown       0.99      0.99      0.99     35516
#         car       1.00      1.00      1.00     36235
#       pedes       0.96      0.98      0.97      8999
#
# avg / total       0.99      0.99      0.99     80750
#
# - Root mean_squared_errors [deg]: 2.50367028639
#  Evaluation one (validation set) epoch  10 /  10
# 100%|██████████| 538/538 [00:44<00:00, 12.00it/s]
# Total loss: 0.234205573797
# - cls loss: 0.151202872396
# - mat loss: 0.755078077316
# - heading loss: 0.0822476223111
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.99      0.98     11805
#         car       0.99      0.99      0.99     12101
#       pedes       0.96      0.91      0.93      2994
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.48981986195
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt

# %%
import os, sys

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import explained_variance_score, mean_squared_error, mean_absolute_error, r2_score

"""
Import model 
"""
sys.path.append( os.path.abspath('../../model') )

from train import *
import model_out_5_heading_3_relu as MODEL



def run_training(out_path):
    
    """ Path """
    model_save_path = os.path.abspath(out_path)
    if not os.path.isdir(model_save_path) : os.mkdir(model_save_path)
        
    """ Parameters """
    GPU_INDEX = 0
    NUM_POINT = 1024
    NUM_CLASSES = 3

    BN_INIT_DECAY = 0.5
    BN_DECAY_DECAY_RATE = 0.5
    BN_DECAY_DECAY_STEP = float(200000)
    BN_DECAY_CLIP = 0.99
    DECAY_STEP = BN_DECAY_DECAY_STEP
    DECAY_RATE = BN_DECAY_DECAY_RATE

    BATCH_SIZE = 50

    MOMENTUM = 0.9

    BASE_LEARNING_RATE = 0.001

    OPTIMIZER = 'adam'

    MAX_EPOCH = 10
    
    HEADING_LOSS_WEIGHT = 0.1


    
    def get_learning_rate(batch):
        learning_rate = tf.train.exponential_decay(
                            BASE_LEARNING_RATE,  # Base learning rate.
                            batch * BATCH_SIZE,  # Current index into the dataset.
                            DECAY_STEP,          # Decay step.
                            DECAY_RATE,          # Decay rate.
                            staircase=True)
        learning_rate = tf.maximum(learning_rate, 0.00001) # CLIP THE LEARNING RATE!
        return learning_rate        

    def get_bn_decay(batch):
        bn_momentum = tf.train.exponential_decay(
                          BN_INIT_DECAY,
                          batch * BATCH_SIZE,
                          BN_DECAY_DECAY_STEP,
                          BN_DECAY_DECAY_RATE,
                          staircase=True)
        bn_decay = tf.minimum(BN_DECAY_CLIP, 1 - bn_momentum)
        return bn_decay

    
    """
    load traing model
    """
    with tf.Graph().as_default():
        with tf.device('/gpu:'+str(GPU_INDEX)):
            
            
            """
            Placeholder
            """
            pointclouds_pl, class_labels_pl, heading_labels_pl = MODEL.placeholder_inputs(BATCH_SIZE, NUM_POINT)
            is_training_pl = tf.placeholder(tf.bool, shape=())
            print(is_training_pl)

            
            """
            decay
            """
            # Note the global_step=batch parameter to minimize. 
            # That tells the optimizer to helpfully increment the 'batch' parameter for you every time it trains.
            batch = tf.Variable(0)
            bn_decay = get_bn_decay(batch)
            tf.summary.scalar('bn_decay', bn_decay)
            
            
            """
            Get model and loss 
            """
            pred, end_points = MODEL.get_model(pointclouds_pl, is_training_pl, bn_decay=bn_decay)
            loss = MODEL.get_loss(pred, class_labels_pl, heading_labels_pl, end_points, h_reg_weight=HEADING_LOSS_WEIGHT)
            tf.summary.scalar('loss', loss)
            
            classify_loss = MODEL.get_classify_loss(pred, class_labels_pl)
            mat_diff_loss = MODEL.get_mat_diff_loss(end_points)
            heading_loss = MODEL.get_heading_loss(pred, heading_labels_pl)
            
            tf.summary.scalar('classify_loss', classify_loss)
            tf.summary.scalar('mat_diff_loss', mat_diff_loss)
            tf.summary.scalar('heading_loss', heading_loss)

            
            """
            Get accuracy 
            """
            correct = tf.equal(tf.argmax(tf.slice(pred, [0,0], [BATCH_SIZE,3]), 1), tf.to_int64(class_labels_pl))
            accuracy = tf.reduce_sum(tf.cast(correct, tf.float32)) / float(BATCH_SIZE)
            tf.summary.scalar('accuracy', accuracy)

            
            """
            Get training operator
            """
            learning_rate = get_learning_rate(batch)
            tf.summary.scalar('learning_rate', learning_rate)
            if OPTIMIZER == 'momentum':
                optimizer = tf.train.MomentumOptimizer(learning_rate, momentum=MOMENTUM)
            elif OPTIMIZER == 'adam':
                optimizer = tf.train.AdamOptimizer(learning_rate)
            train_op = optimizer.minimize(loss, global_step=batch)

            
            """
            Add ops to save and restore all the variables.
            """
            saver = tf.train.Saver()

            
        """
        Create a session
        """
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        config.allow_soft_placement = True
        config.log_device_placement = False
        sess = tf.Session(config=config)

        
        """
        Add summary writers
        merged = tf.merge_all_summaries()
        """
        merged = tf.summary.merge_all()

        train_writer_path = os.path.abspath( os.path.join(model_save_path, 'train') )
        if os.path.isdir(train_writer_path): os.system('rm -r {}'.format(train_writer_path))
        os.mkdir(train_writer_path)

        test_writer_path = os.path.abspath( os.path.join(model_save_path, 'test') )
        if os.path.isdir(test_writer_path): os.system('rm -r {}'.format(test_writer_path))
        os.mkdir(test_writer_path)


        train_writer = tf.summary.FileWriter(train_writer_path, sess.graph)
        test_writer = tf.summary.FileWriter(test_writer_path)

        
        """
        Init variables
        """
        init = tf.global_variables_initializer()
        # To fix the bug introduced in TF 0.12.1 as in
        # http://stackoverflow.com/questions/41543774/invalidargumenterror-for-tensor-bool-tensorflow-0-12-1
        #sess.run(init)
        sess.run(init, {is_training_pl: True})

        ops = {'pointclouds_pl': pointclouds_pl,
               'class_labels_pl': class_labels_pl,
               'heading_labels_pl': heading_labels_pl,
               'is_training_pl': is_training_pl,
               'pred': pred,
               'loss': loss,
               'classify_loss': classify_loss,
               'mat_diff_loss': mat_diff_loss,
               'heading_loss': heading_loss,
               'train_op': train_op,
               'merged': merged,
               'step': batch}


        for epoch in range(MAX_EPOCH):

            ## Training
            print "\n\n Train one epoch %3d / %3d" % (epoch+1, MAX_EPOCH)
            sys.stdout.flush()

            is_training = True

            
            """
            Shuffle train files
            """
            train_file_idxs = np.arange(0, data_train.shape[0])
            np.random.shuffle(train_file_idxs)

            current_data = data_train[train_file_idxs] 
            current_class_label = class_label_train[train_file_idxs]
            current_heading_label = heading_label_train[train_file_idxs]
            
            current_class_label.reshape((data_train.shape[0],))
            current_heading_label.reshape((data_train.shape[0],))

            
            """
            Evaluation metric
            """
            class_results = []
            heading_results = []
            

            """
            Run batch training
            """
            num_batches = current_data.shape[0] // BATCH_SIZE

            for batch_idx in trange(num_batches):

                start_idx = batch_idx * BATCH_SIZE
                end_idx = (batch_idx+1) * BATCH_SIZE           

                # Augment batched point clouds by rotation and jittering
                rotated_data = provider.rotate_point_cloud(current_data[start_idx:end_idx, :, :])
                jittered_data = provider.jitter_point_cloud(rotated_data)

                # Reashape
                current_class_label_reshape = current_class_label[start_idx:end_idx].reshape((BATCH_SIZE,))
                current_heading_label_reshape = current_heading_label[start_idx:end_idx].reshape((BATCH_SIZE,))

                feed_dict = {ops['pointclouds_pl']: jittered_data,
                             ops['class_labels_pl']: current_class_label_reshape,
                             ops['heading_labels_pl']: current_heading_label_reshape,
                             ops['is_training_pl']: is_training,}

                summary, step, _, loss_val,loss_cls,loss_mat,loss_hea, pred_val = sess.run([ops['merged'], 
                                                                 ops['step'],
                                                                 ops['train_op'], 
                                                                 ops['loss'], 
                                                                 ops['classify_loss'],
                                                                 ops['mat_diff_loss'],
                                                                 ops['heading_loss'],
                                                                 ops['pred']], feed_dict=feed_dict)

                train_writer.add_summary(summary, step)
                
                """
                Evaluation
                """
                # heading
                heading_results.extend(pred_val[:,3])
                # class
                pred_val_class = np.argmax(pred_val[:,:3], 1)
                class_results.extend(pred_val_class)
            
            """
            Results
            """
            ## Loss
            print "Total loss: {}".format(np.mean(loss_val))
            print "- cls loss: {}".format(np.mean(loss_cls))
            print "- mat loss: {}".format(np.mean(loss_mat))
            print "- heading loss: {}".format(np.mean(loss_hea))
            
            
            
            ## Classification
            prediction = np.array(class_results)
            ground_truth = np.array(current_class_label[:num_batches*BATCH_SIZE])
            cm = confusion_matrix(ground_truth, prediction)
            label_list = ['unknown', 'car', 'pedes']
            print(classification_report(ground_truth, prediction, target_names=label_list))
            
            ## Heading
            y_pred = np.asarray(heading_results)
            y_true = np.asarray(current_heading_label[:num_batches*BATCH_SIZE])
            y_pred = y_pred.reshape(y_true.shape)

            error = np.abs(y_true - y_pred)
            rmse = np.square( np.mean (error**2) )
        #     print('- Explained_variance_score: {}'.format(explained_variance_score(y_true, y_pred)))
        #     print('- R2_score: {}'.format(r2_score(y_true, y_pred)))
            print('- Root mean_squared_errors [deg]: {}'.format(rmse * 360.))
            plt.plot(y_true, label = 'truth')
            plt.plot(y_pred, label = 'prediction')
            plt.legend()
            plt.show()    
            
            """
            Evaluation using validation set    
            """
            
            print " Evaluation one (validation set) epoch %3d / %3d" % (epoch+1, MAX_EPOCH)
            sys.stdout.flush()

            is_training = False


            """
            Evaluation metric
            """
            class_results = []
            heading_results = []
                       
            
            """
            Shuffle validation files
            """
            file_idxs = np.arange(0, data_vali.shape[0])
            np.random.shuffle(file_idxs)

            current_data = data_vali[file_idxs]
            current_class_label = class_label_vali[file_idxs]
            current_heading_label = heading_label_vali[file_idxs]

            num_batches = current_data.shape[0] // BATCH_SIZE

            
            """
            Run batch validation
            """
            num_batches = current_data.shape[0] // BATCH_SIZE

            for batch_idx in trange(num_batches):

                start_idx = batch_idx * BATCH_SIZE
                end_idx = (batch_idx+1) * BATCH_SIZE

                
                """
                Reashape
                """
                current_class_label_reshape = current_class_label[start_idx:end_idx].reshape((BATCH_SIZE,))
                current_heading_label_reshape = current_heading_label[start_idx:end_idx].reshape((BATCH_SIZE,))

                
                """
                Feed dict
                """
                feed_dict = {ops['pointclouds_pl']: current_data[start_idx:end_idx, :, :],
                             ops['class_labels_pl']: current_class_label_reshape,
                             ops['heading_labels_pl']: current_heading_label_reshape,
                             ops['is_training_pl']: is_training}
                
                """
                Run session
                """
                summary, step, loss_val, loss_cls, loss_mat, loss_hea, pred_val = sess.run([ops['merged'], ops['step'],
                                                              ops['loss'], 
                                                              ops['classify_loss'], 
                                                              ops['mat_diff_loss'], 
                                                              ops['heading_loss'], 
                                                              ops['pred']], feed_dict=feed_dict)

                test_writer.add_summary(summary, step)

                """
                Evaluation
                """
                # heading
                heading_results.extend(pred_val[:,3])

                pred_val_class = np.argmax(pred_val[:,:3], 1)
                class_results.extend(pred_val_class)
            
            ## Loss
            print "Total loss: {}".format(np.mean(loss_val))
            print "- cls loss: {}".format(np.mean(loss_cls))
            print "- mat loss: {}".format(np.mean(loss_mat))
            print "- heading loss: {}".format(np.mean(loss_hea))
            
            
            ## Classification
            prediction = np.array(class_results)
            ground_truth = np.array(current_class_label[:num_batches*BATCH_SIZE])
            cm = confusion_matrix(ground_truth, prediction)
            label_list = ['unknown', 'car', 'pedes']
            print(classification_report(ground_truth, prediction, target_names=label_list))
            
            ## Heading
            y_pred = np.asarray(heading_results)
            y_true = np.asarray(current_heading_label[:num_batches*BATCH_SIZE])
            y_pred = y_pred.reshape(y_true.shape)

            error = np.abs(y_true - y_pred)
            rmse = np.square( np.mean (error**2) )
        #     print('- Explained_variance_score: {}'.format(explained_variance_score(y_true, y_pred)))
        #     print('- R2_score: {}'.format(r2_score(y_true, y_pred)))
            print('- Root mean_squared_errors [deg]: {}'.format(rmse * 360.))
            plt.plot(y_true, label = 'truth')
            plt.plot(y_pred, label = 'prediction')
            plt.legend()
            plt.show() 
                
            """
            Save the variables to disk.
            """
#             if ( epoch + 1 ) % 10 == 0:
            save_path = saver.save(sess, os.path.join(model_save_path, "model.ckpt"))
            print "Model saved in file: %s" % save_path

                
# option 1: execute code with extra process
p = multiprocessing.Process(target=run_training, args = ('./model_out_1',))
p.start()
p.join()
# Out:
# Tensor("Placeholder_3:0", shape=(), dtype=bool, device=/device:GPU:0)
#
#
#  Train one epoch   1 /  10
# 100%|██████████| 1615/1615 [09:38<00:00,  2.79it/s]
# Total loss: 0.567814588547
# - cls loss: 0.514837086201
# - mat loss: 42.8018417358
# - heading loss: 0.101756699383
#              precision    recall  f1-score   support
#
#     unknown       0.72      0.66      0.69     35517
#         car       0.73      0.79      0.75     36234
#       pedes       0.82      0.84      0.83      8999
#
# avg / total       0.74      0.74      0.74     80750
#
# - Root mean_squared_errors [deg]: 5.37350904197
#  Evaluation one (validation set) epoch   1 /  10
# 100%|██████████| 538/538 [00:45<00:00, 11.74it/s]
# Total loss: 0.251296550035
# - cls loss: 0.225522577763
# - mat loss: 16.6372947693
# - heading loss: 0.091366790235
#              precision    recall  f1-score   support
#
#     unknown       0.83      0.87      0.85     11804
#         car       0.91      0.84      0.87     12099
#       pedes       0.84      0.92      0.88      2997
#
# avg / total       0.87      0.86      0.86     26900
#
# - Root mean_squared_errors [deg]: 2.79857145622
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   2 /  10
# 100%|██████████| 1615/1615 [09:38<00:00,  2.79it/s]
# Total loss: 0.125624224544
# - cls loss: 0.107358075678
# - mat loss: 9.80840301514
# - heading loss: 0.0845774486661
#              precision    recall  f1-score   support
#
#     unknown       0.89      0.87      0.88     35517
#         car       0.91      0.91      0.91     36233
#       pedes       0.88      0.93      0.90      9000
#
# avg / total       0.89      0.89      0.89     80750
#
# - Root mean_squared_errors [deg]: 3.00506651402
#  Evaluation one (validation set) epoch   2 /  10
# 100%|██████████| 538/538 [00:45<00:00, 11.92it/s]
# Total loss: 0.0383705161512
# - cls loss: 0.0210616104305
# - mat loss: 8.60804748535
# - heading loss: 0.0870085805655
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.95      0.96     11804
#         car       0.98      1.00      0.99     12100
#       pedes       0.88      0.91      0.89      2996
#
# avg / total       0.97      0.97      0.97     26900
#
# - Root mean_squared_errors [deg]: 2.56383039057
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   3 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 0.254253655672
# - cls loss: 0.241222038865
# - mat loss: 4.50349617004
# - heading loss: 0.0852811709046
#              precision    recall  f1-score   support
#
#     unknown       0.92      0.90      0.91     35518
#         car       0.93      0.94      0.94     36232
#       pedes       0.88      0.94      0.91      9000
#
# avg / total       0.92      0.92      0.92     80750
#
# - Root mean_squared_errors [deg]: 2.58161947131
#  Evaluation one (validation set) epoch   3 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.98it/s]
# Total loss: 0.0271245036274
# - cls loss: 0.0173512343317
# - mat loss: 2.48350763321
# - heading loss: 0.0728976130486
#              precision    recall  f1-score   support
#
#     unknown       0.96      0.98      0.97     11804
#         car       0.99      0.99      0.99     12101
#       pedes       0.91      0.89      0.90      2995
#
# avg / total       0.97      0.97      0.97     26900
#
# - Root mean_squared_errors [deg]: 2.52168215811
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   4 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 0.0363598205149
# - cls loss: 0.0260004028678
# - mat loss: 1.78352451324
# - heading loss: 0.085758946836
#              precision    recall  f1-score   support
#
#     unknown       0.97      0.96      0.96     35514
#         car       0.98      0.98      0.98     36237
#       pedes       0.91      0.96      0.93      8999
#
# avg / total       0.97      0.97      0.97     80750
#
# - Root mean_squared_errors [deg]: 2.55059368908
#  Evaluation one (validation set) epoch   4 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.98it/s]
# Total loss: 0.015026666224
# - cls loss: 0.00596140045673
# - mat loss: 2.02525663376
# - heading loss: 0.0704000890255
#              precision    recall  f1-score   support
#
#     unknown       0.96      0.98      0.97     11806
#         car       0.99      0.99      0.99     12100
#       pedes       0.94      0.84      0.89      2994
#
# avg / total       0.97      0.97      0.97     26900
#
# - Root mean_squared_errors [deg]: 2.61349182576
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   5 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 0.0460609011352
# - cls loss: 0.0373136363924
# - mat loss: 2.00816726685
# - heading loss: 0.0673909932375
#              precision    recall  f1-score   support
#
#     unknown       0.97      0.96      0.97     35515
#         car       0.98      0.98      0.98     36235
#       pedes       0.93      0.96      0.94      9000
#
# avg / total       0.97      0.97      0.97     80750
#
# - Root mean_squared_errors [deg]: 2.54200961441
#  Evaluation one (validation set) epoch   5 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.99it/s]
# Total loss: 0.0542215406895
# - cls loss: 0.042915482074
# - mat loss: 1.85800170898
# - heading loss: 0.0944805294275
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.99      0.98     11803
#         car       0.99      1.00      0.99     12101
#       pedes       0.95      0.89      0.92      2996
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.4884111993
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   6 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 0.0693636238575
# - cls loss: 0.0588181987405
# - mat loss: 2.60985088348
# - heading loss: 0.079355686903
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.98      0.98     35516
#         car       0.99      0.99      0.99     36238
#       pedes       0.96      0.97      0.96      8996
#
# avg / total       0.98      0.98      0.98     80750
#
# - Root mean_squared_errors [deg]: 2.51970922574
#  Evaluation one (validation set) epoch   6 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.98it/s]
# Total loss: 0.143069595098
# - cls loss: 0.132511943579
# - mat loss: 1.351146698
# - heading loss: 0.0920649990439
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.98      0.98     11799
#         car       0.99      0.99      0.99     12105
#       pedes       0.94      0.91      0.92      2996
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.49184794724
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   7 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 0.0327375940979
# - cls loss: 0.0237575676292
# - mat loss: 1.41516470909
# - heading loss: 0.0756486281753
#              precision    recall  f1-score   support
#
#     unknown       0.99      0.98      0.99     35516
#         car       0.99      0.99      0.99     36235
#       pedes       0.97      0.97      0.97      8999
#
# avg / total       0.99      0.99      0.99     80750
#
# - Root mean_squared_errors [deg]: 2.51636551693
#  Evaluation one (validation set) epoch   7 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.97it/s]
# Total loss: 0.0179908983409
# - cls loss: 0.00775369442999
# - mat loss: 1.05973684788
# - heading loss: 0.0917746722698
#              precision    recall  f1-score   support
#
#     unknown       0.98      0.99      0.99     11798
#         car       0.99      1.00      0.99     12108
#       pedes       0.96      0.90      0.93      2994
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.48359277844
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   8 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 0.0195608250797
# - cls loss: 0.00867402553558
# - mat loss: 1.43246495724
# - heading loss: 0.094543337822
#              precision    recall  f1-score   support
#
#     unknown       0.99      0.99      0.99     35514
#         car       1.00      0.99      1.00     36236
#       pedes       0.98      0.98      0.98      9000
#
# avg / total       0.99      0.99      0.99     80750
#
# - Root mean_squared_errors [deg]: 2.5096591562
#  Evaluation one (validation set) epoch   8 /  10
# 100%|██████████| 538/538 [00:44<00:00, 12.00it/s]
# Total loss: 0.00826111342758
# - cls loss: 0.00129811302759
# - mat loss: 0.814113259315
# - heading loss: 0.061488866806
#              precision    recall  f1-score   support
#
#     unknown       0.99      0.99      0.99     11804
#         car       0.99      1.00      0.99     12098
#       pedes       0.96      0.91      0.93      2998
#
# avg / total       0.98      0.98      0.98     26900
#
# - Root mean_squared_errors [deg]: 2.49086089432
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch   9 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 0.0166891478002
# - cls loss: 0.0092804338783
# - mat loss: 0.930377721786
# - heading loss: 0.0647833645344
#              precision    recall  f1-score   support
#
#     unknown       0.99      0.99      0.99     35514
#         car       1.00      1.00      1.00     36236
#       pedes       0.98      0.99      0.99      9000
#
# avg / total       0.99      0.99      0.99     80750
#
# - Root mean_squared_errors [deg]: 2.50783424824
#  Evaluation one (validation set) epoch   9 /  10
# 100%|██████████| 538/538 [00:44<00:00, 11.98it/s]
# Total loss: 0.0190333463252
# - cls loss: 0.0100139072165
# - mat loss: 0.590515494347
# - heading loss: 0.0842892453074
#              precision    recall  f1-score   support
#
#     unknown       0.99      0.99      0.99     11798
#         car       0.99      1.00      0.99     12106
#       pedes       0.96      0.92      0.94      2996
#
# avg / total       0.99      0.99      0.99     26900
#
# - Root mean_squared_errors [deg]: 2.53044141456
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt
#
#
#  Train one epoch  10 /  10
# 100%|██████████| 1615/1615 [09:36<00:00,  2.80it/s]
# Total loss: 0.00962506514043
# - cls loss: 0.000769998005126
# - mat loss: 1.11818814278
# - heading loss: 0.0773687884212
#              precision    recall  f1-score   support
#
#     unknown       0.99      0.99      0.99     35516
#         car       1.00      1.00      1.00     36235
#       pedes       0.99      0.99      0.99      8999
#
# avg / total       0.99      0.99      0.99     80750
#
# - Root mean_squared_errors [deg]: 2.50251760706
#  Evaluation one (validation set) epoch  10 /  10
# 100%|██████████| 538/538 [00:44<00:00, 12.06it/s]
# Total loss: 0.236155971885
# - cls loss: 0.227024406195
# - mat loss: 0.908493936062
# - heading loss: 0.0822307467461
#              precision    recall  f1-score   support
#
#     unknown       0.99      0.99      0.99     11805
#         car       0.99      1.00      0.99     12101
#       pedes       0.96      0.92      0.94      2994
#
# avg / total       0.99      0.99      0.99     26900
#
# - Root mean_squared_errors [deg]: 2.4863980338
# Model saved in file: /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181206/model_out_1/model.ckpt

# %%
Total loss: 1.48332905769
- cls loss: 0.67468637228
- mat loss: 1.64805793762
- heading loss: 0.0806994661689
    
Total loss: 0.236155971885
- cls loss: 0.227024406195
- mat loss: 0.908493936062
- heading loss: 0.0822307467461
