# %% [markdown]
# # Point cloud generation from mesh
#
# ## Dedenencies
#
# * numpy
# * matplotlib
# * numpy-stl
#   - pip install numpy-stl
#
# ## Decription
# Convert mesh to point cloud
#
# * 3D CAD Model
#   - ![CAD](./image/cad_model.png)
#
# * Mesh Model
#   - ![mesh](./image/mesh_model.png)
#
# * Point cloud
#   - ![pointcloud](./image/pointcloud.png)

# %% [markdown]
# ## Load mesh files

# %%
import numpy as np
from stl import mesh

print mesh.__file__
mymesh = mesh.Mesh.from_file('/media/kyungpyo/SmartCarContest/MasterThesisProject/new_dataset/dataset/stl_files/00_total/car/3d-Car-Model.stl')
# Out:
# /home/kyungpyo/.local/lib/python2.7/site-packages/stl/mesh.pyc

# %% [markdown]
# ## Sampling point cloud from mesh (test)

# %%
"""
Reference: https://medium.com/@daviddelaiglesiacastro/3d-point-cloud-generation-from-3d-triangular-mesh-bbb602ecf238
"""
n = 10000

def triangle_area_multi(v1, v2, v3):
    return 0.5 * np.linalg.norm( np.cross(v2-v1, v3-v1), axis = 1)

areas = triangle_area_multi(mymesh.v0, mymesh.v1, mymesh.v2)

probabilities = areas / areas.sum()

## select triangles to sample point cloud
weighted_random_indices = np.random.choice( range(len(areas)), size=n, p=probabilities)

v0_xyz = mymesh.v0[weighted_random_indices]
v1_xyz = mymesh.v1[weighted_random_indices]
v2_xyz = mymesh.v2[weighted_random_indices]

u = np.random.rand(n,1)
v = np.random.rand(n,1)
is_a_problem = u + v > 1

u[is_a_problem] = 1 - u[is_a_problem]
v[is_a_problem] = 1 - v[is_a_problem]

w = 1 - (u + v)

result_xyz = (v0_xyz * u) + (v1_xyz * v) + (v2_xyz * w)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-677d3cf8e044> in <module>()
#      12
#      13 ## select triangles to sample point cloud
# ---> 14 weighted_random_indices = np.random.choice( range(len(areas)), size=n, p=probabilities)
#      15
#      16 v0_xyz = mymesh.v0[weighted_random_indices]
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: a must be non-empty

# %%
mymesh.v0
# Out:
# array([], shape=(0, 3), dtype=float32)

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection, Line3DCollection

def display_point_cloud_box_ax_test(ax, pts):
    
    # display point cloud
    ax.scatter(pts[:,0], pts[:,1], pts[:,2], s=5, alpha = 1.0)
    
    # display center point
    cp = np.mean(pts, axis = 0)
    ax.scatter(cp[0], cp[1], cp[2], c='r', s=5)
    
    # display bounding box   
    cube_definition_array = [
        np.array(list(item))
        for item in find_cube_definition(pts)
    ]
    points = []
    points += cube_definition_array
    vectors = [
        cube_definition_array[1] - cube_definition_array[0],
        cube_definition_array[2] - cube_definition_array[0],
        cube_definition_array[3] - cube_definition_array[0]
    ]

    points += [cube_definition_array[0] + vectors[0] + vectors[1]]
    points += [cube_definition_array[0] + vectors[0] + vectors[2]]
    points += [cube_definition_array[0] + vectors[1] + vectors[2]]
    points += [cube_definition_array[0] + vectors[0] + vectors[1] + vectors[2]]

    points = np.array(points)

    edges = [
        [points[0], points[3], points[5], points[1]],
        [points[1], points[5], points[7], points[4]],
        [points[4], points[2], points[6], points[7]],
        [points[2], points[6], points[3], points[0]],
        [points[0], points[2], points[4], points[1]],
        [points[3], points[6], points[7], points[5]]
    ]

    faces = Poly3DCollection(edges, linewidths=0.1, edgecolors='k')
    faces.set_facecolor((0,0,1,0.05))
    
    ax.add_collection3d(faces)
    
    # Edges of the cube
    ax.scatter(points[:,0], points[:,1], points[:,2], s=0)

    # make axis equal
    p_min = np.min(points, axis=0)
    p_max = np.max(points, axis=0)
    max_range = np.array([p_max[0]-p_min[0], p_max[1]-p_min[1], p_max[2]-p_min[2]]).max() / 2.0

    mid_x = (p_max[0]+p_min[0]) * 0.5
    mid_y = (p_max[1]+p_min[1]) * 0.5
    mid_z = (p_max[2]+p_min[2]) * 0.5
    ax.set_xlim(mid_x - max_range, mid_x + max_range)
    ax.set_ylim(mid_y - max_range, mid_y + max_range)
    ax.set_zlim(mid_z - max_range, mid_z + max_range)
    
    return ax


def find_cube_definition(pts):
    p_min = np.min(pts, axis = 0)
    p_max = np.max(pts, axis = 0)
    return [ (p_min[0],p_min[1],p_min[2]), 
            (p_max[0],p_min[1],p_min[2]), 
            (p_min[0],p_max[1],p_min[2]), 
            (p_min[0],p_min[1],p_max[2])]
def resample_point_cloud(pts, resample_ratio):
    step = int(1./resample_ratio)
    idx = range(0, len(pts), step)
    return pts[idx]

# %%
# %matplotlib qt
# %matplotlib qt
# %matplotlib qt
# %matplotlib qt
fig = plt.figure(figsize = (10,10))

ax = fig.add_subplot(1,1,1, projection='3d')

display_point_cloud_box_ax_test(ax, result_xyz)
ax.view_init(elev=100, azim=250)

plt.axis('off')
plt.show()

# %% [markdown]
# ## Function implementation

# %%
def pointcloud_from_mesh(v0,v1,v2, n):
    """
    input:
        v0, v1, v2: vertex list of meshs
        n = number of generated points
    output:
        point cloud: n points
    reference:
        https://medium.com/@daviddelaiglesiacastro/3d-point-cloud-generation-from-3d-triangular-mesh-bbb602ecf238
    """
    
    ## Sample point cloud uniformly using areas
    areas = 0.5 * np.linalg.norm( np.cross(v1-v0, v2-v0), axis = 1 )
    probabilities = areas / areas.sum()

    # select triangles to sample point cloud
    weighted_random_indices = np.random.choice( range(len(areas)), size=n, p=probabilities)

    v0_xyz = v0[weighted_random_indices]
    v1_xyz = v1[weighted_random_indices]
    v2_xyz = v2[weighted_random_indices]

    ## random sample
    u = np.random.rand(n,1)
    v = np.random.rand(n,1)
    is_a_problem = u + v > 1

    u[is_a_problem] = 1 - u[is_a_problem]
    v[is_a_problem] = 1 - v[is_a_problem]

    w = 1 - (u + v)

    return (v0_xyz * u) + (v1_xyz * v) + (v2_xyz * w)

# %% [markdown]
# ## Run all files

# %%
import os
import numpy as np
from stl import mesh

class_name = 'car'

root_path = os.path.abspath('./dataset/stl_files/00_total/car/')
out_path = os.path.abspath('./dataset/point_dataset/car')
try:
    if not(os.path.isdir(out_path)):
        os.makedirs(os.path.join(out_path))
except OSError as e:
    if e.errno != errno.EEXIST:
        print("Failed to create directory!!!!!")
        raise
    
"""
Not converted files
"""
root_nc_path = os.path.join(root_path, 'not_conversion')
try:
    if not(os.path.isdir(root_nc_path)):
        os.makedirs(os.path.join(root_nc_path))
except OSError as e:
    if e.errno != errno.EEXIST:
        print("Failed to create directory!!!!!")
        raise
    

## find ".stl" files
fname = []
for root,d_names,f_names in os.walk(root_path):
    for f in f_names:
        if f.split('.')[-1] == 'stl':
            fname.append(os.path.join(root, f))

## convert to numpy point cloud
for i in range ( len ( fname ) ):
    print "File path:", fname[i].split("/")[-1]

    try:
    
        meshdata = mesh.Mesh.from_file(fname[i])
        
        pc = pointcloud_from_mesh(meshdata.v0, meshdata.v1, meshdata.v2, n = 100000)
    
        out_file_name = "{}_{:04}".format(class_name, i)

        out_file_path = os.path.join(out_path, out_file_name)

        np.save(out_file_path, pc)

        del pc

        print "Save file:", out_file_name 
    
    except AssertionError:
        
        meshdata_nc_path = os.path.join(root_nc_path, fname[i].split("/")[-1])
        
        os.system( "mv {} {}/".format(fname[i], root_nc_path) )
        
        continue
        
    except ValueError:
        meshdata_nc_path = os.path.join(root_nc_path, fname[i].split("/")[-1])
        
        os.system( "mv {} {}/".format(fname[i], root_nc_path) )
        
        continue
# Out:
# File path: 1.stl
# Save file: car_0000
# File path: 3d-Car-Model.stl
# File path: as-1-mr2.stl
# Save file: car_0002
# File path: Astin-DB9.stl
# Save file: car_0003
# File path: Audi-TT.stl
# Save file: car_0004
# File path: Azerant.stl
# Save file: car_0005
# File path: beetle.stl
# File path: BRZ4.stl
# File path: bus.stl
# Save file: car_0008
# File path: BUS_2.stl
# File path: BUS_3.stl
# File path: car.stl
# Save file: car_0011
# File path: car_0001.stl
# File path: car_0002.stl
# Save file: car_0013
# File path: car_0003.stl
# File path: car_0004.stl
# File path: car_0005.stl
# File path: car_0006.stl
# File path: car_0008.stl
# Save file: car_0018
# File path: car_0009.stl
# File path: car_0010.stl
# File path: car_0011.stl
# File path: car_0012.stl
# File path: car_0013.stl
# File path: car_0014.stl
# File path: car_0015.stl
# File path: car_0016.stl
# File path: car_0017.stl
# File path: car_0018.stl
# Save file: car_0028
# File path: car_0019.stl
# File path: car_0020.stl
# File path: car_0022.stl
# File path: car_0023.stl
# File path: car_0024.stl
# File path: car_0028.stl
# File path: car_0029.stl
# File path: car_0032.stl
# File path: car_0033.stl
# Save file: car_0037
# File path: car_0034.stl
# File path: car_0035.stl
# File path: car_0036.stl
# File path: car_0037.stl
# File path: car_0038.stl
# File path: car_0039.stl
# Save file: car_0043
# File path: car_0040.stl
# File path: car_0043.stl
# File path: car_0044.stl
# File path: car_0045.stl
# File path: car_0047.stl
# File path: car_0048.stl
# File path: car_0049.stl
# File path: car_0052.stl
# File path: car_0053.stl
# File path: car_0054.stl
# File path: car_0056.stl
# File path: car_0057.stl
# File path: car_0058.stl
# File path: car_0059.stl
# File path: car_0060.stl
# File path: car_0061.stl
# File path: car_0062.stl
# File path: car_0063.stl
# File path: car_0064.stl
# Save file: car_0062
# File path: car_0065.stl
# File path: car_0066.stl
# File path: car_0068.stl
# File path: car_0070.stl
# File path: car_0071.stl
# Save file: car_0067
# File path: car_0072.stl
# Save file: car_0068
# File path: car_0073.stl
# File path: car_0076.stl
# File path: car_0077.stl
# Save file: car_0071
# File path: car_0079.stl
# File path: car_0080.stl
# File path: car_0081.stl
# File path: car_0082.stl
# File path: car_0083.stl
# File path: car_0084.stl
# File path: car_0085.stl
# File path: car_0086.stl
# File path: car_0087.stl
# File path: car_0088.stl
# File path: car_0089.stl
# File path: car_0090.stl
# File path: car_0091.stl
# File path: car_0092.stl
# File path: car_0093.stl
# File path: car_0094.stl
# File path: car_0095.stl
# File path: car_0096.stl
# File path: car_0007.stl
# File path: car_0030.stl
# Save file: car_0091
# File path: car_0055.stl
# File path: car_0078.stl
# File path: car_0097.stl
# Save file: car_0094
# File path: car_0118.stl
# File path: car_0141.stl
# File path: car_0163.stl
# Save file: car_0097
# File path: car_0186.stl
# Save file: car_0098
# File path: car_0206.stl
# File path: car_0226.stl
# Save file: car_0100
# File path: car_0249.stl
# File path: car_0272.stl
# File path: car_0293.stl
# File path: car_0098.stl
# Save file: car_0104
# File path: car_0099.stl
# File path: car_0101.stl
# File path: car_0103.stl
# File path: car_0104.stl
# File path: car_0105.stl
# Save file: car_0109
# File path: car_0106.stl
# Save file: car_0110
# File path: car_0107.stl
# File path: car_0108.stl
# File path: car_0109.stl
# File path: car_0110.stl
# File path: car_0111.stl
# File path: car_0112.stl
# File path: car_0113.stl
# File path: car_0114.stl
# File path: car_0115.stl
# Save file: car_0119
# File path: car_0116.stl
# Save file: car_0120
# File path: car_0117.stl
# File path: car_0120.stl
# Save file: car_0122
# File path: car_0121.stl
# File path: car_0122.stl
# File path: car_0124.stl
# File path: car_0125.stl
# File path: car_0127.stl
# File path: car_0128.stl
# File path: car_0129.stl
# File path: car_0130.stl
# File path: car_0131.stl
# File path: car_0132.stl
# File path: car_0134.stl
# File path: car_0135.stl
# File path: car_0136.stl
# File path: car_0137.stl
# File path: car_0138.stl
# File path: car_0139.stl
# File path: car_0140.stl
# File path: car_0142.stl
# File path: car_0143.stl
# File path: car_0145.stl
# File path: car_0146.stl
# File path: car_0147.stl
# File path: car_0148.stl
# File path: car_0149.stl
# Save file: car_0146
# File path: car_0150.stl
# Save file: car_0147
# File path: car_0152.stl
# File path: car_0153.stl
# File path: car_0154.stl
# Save file: car_0150
# File path: car_0155.stl
# File path: car_0156.stl
# File path: car_0157.stl
# File path: car_0158.stl
# File path: car_0159.stl
# File path: car_0160.stl
# File path: car_0161.stl
# File path: car_0164.stl
# Save file: car_0158
# File path: car_0165.stl
# File path: car_0166.stl
# File path: car_0169.stl
# Save file: car_0161
# File path: car_0170.stl
# Save file: car_0162
# File path: car_0171.stl
# File path: car_0172.stl
# File path: car_0173.stl
# Save file: car_0165
# File path: car_0174.stl
# File path: car_0175.stl
# File path: car_0176.stl
# File path: car_0177.stl
# File path: car_0179.stl
# File path: car_0181.stl
# File path: car_0182.stl
# File path: car_0183.stl
# File path: car_0184.stl
# File path: car_0185.stl
# File path: car_0187.stl
# File path: car_0188.stl
# File path: car_0190.stl
# File path: car_0191.stl
# Save file: car_0179
# File path: car_0192.stl
# File path: car_0193.stl
# File path: car_0194.stl
# File path: car_0195.stl
# File path: car_0196.stl
# Save file: car_0184
# File path: car_0197.stl
# File path: car_0198.stl
# File path: car_0199.stl
# File path: car_0200.stl
# File path: car_0201.stl
# File path: car_0202.stl
# File path: car_0203.stl
# File path: car_0204.stl
# File path: car_0205.stl
# File path: car_0207.stl
# File path: car_0208.stl
# File path: car_0209.stl
# File path: car_0210.stl
# Save file: car_0197
# File path: car_0211.stl
# File path: car_0212.stl
# File path: car_0213.stl
# File path: car_0214.stl
# File path: car_0215.stl
# File path: car_0216.stl
# File path: car_0217.stl
# Save file: car_0204
# File path: car_0218.stl
# File path: car_0220.stl
# File path: car_0221.stl
# File path: car_0222.stl
# File path: car_0223.stl
# File path: car_0224.stl
# File path: car_0225.stl
# File path: car_0227.stl
# File path: car_0228.stl
# File path: car_0229.stl
# File path: car_0230.stl
# File path: car_0231.stl
# File path: car_0232.stl
# File path: car_0233.stl
# File path: car_0234.stl
# File path: car_0235.stl
# File path: car_0237.stl
# File path: car_0238.stl
# File path: car_0239.stl
# File path: car_0240.stl
# File path: car_0241.stl
# File path: car_0242.stl
# File path: car_0243.stl
# File path: car_0245.stl
# File path: car_0247.stl
# File path: car_0250.stl
# File path: car_0251.stl
# File path: car_0252.stl
# Save file: car_0232
# File path: car_0253.stl
# File path: car_0254.stl
# File path: car_0255.stl
# File path: car_0256.stl
# File path: car_0257.stl
# Save file: car_0237
# File path: car_0258.stl
# File path: car_0259.stl
# File path: car_0260.stl
# File path: car_0261.stl
# File path: car_0262.stl
# File path: car_0265.stl
# File path: car_0266.stl
# File path: car_0267.stl
# File path: car_0270.stl
# File path: car_0271.stl
# Save file: car_0247
# File path: car_0273.stl
# File path: car_0275.stl
# File path: car_0276.stl
# Save file: car_0250
# File path: car_0277.stl
# File path: car_0278.stl
# File path: car_0280.stl
# File path: car_0281.stl
# File path: car_0283.stl
# File path: car_0284.stl
# File path: car_0285.stl
# File path: car_0286.stl
# Save file: car_0258
# File path: car_0287.stl
# File path: car_0288.stl
# File path: car_0289.stl
# File path: car_0290.stl
# Save file: car_0262
# File path: car_0291.stl
# File path: car_0292.stl
# File path: car_0294.stl
# Save file: car_0265
# File path: car_0295.stl
# File path: car_0296.stl
# File path: car_0297.stl
# Save file: car_0268
# File path: car_2.stl
# Save file: car_0269
# File path: Cement-Mixer-Truck.stl
# Save file: car_0270
# File path: further02.stl
# File path: GLX_400.stl
# Save file: car_0272
# File path: Golf_Mk5_OBJ.stl
# File path: LAMBO-H-animation.stl
# File path: Lancer-Evolution-model.stl
# Save file: car_0275
# File path: Lancia-Ypsilon.stl
# File path: Mercedes-Benz-CL600-2007-OBJ.stl
# File path: MitsubishiLanserEvo-obj.stl
# Save file: car_0278
# File path: nixanz.stl
# Save file: car_0279
# File path: pcikup.stl
# Save file: car_0280
# File path: R8-Low-Poly-Turbosquid2.stl
# Save file: car_0281
# File path: rio.stl
# Save file: car_0282
# File path: Samand400.stl
# Save file: car_0283
# File path: soarer_OBJ.stl
# File path: v40cc.stl
# File path: VAZ2106.stl

# %%
import os
import numpy as np
from stl import mesh

class_name = 'pedestrian'

root_path = os.path.abspath('./dataset/stl_files/00_total/pedestrian/')
out_path = os.path.abspath('./dataset/point_dataset/pedestrian')
try:
    if not(os.path.isdir(out_path)):
        os.makedirs(os.path.join(out_path))
except OSError as e:
    if e.errno != errno.EEXIST:
        print("Failed to create directory!!!!!")
        raise
    
"""
Not converted files
"""
root_nc_path = os.path.join(root_path, 'not_conversion')
try:
    if not(os.path.isdir(root_nc_path)):
        os.makedirs(os.path.join(root_nc_path))
except OSError as e:
    if e.errno != errno.EEXIST:
        print("Failed to create directory!!!!!")
        raise
    

## find ".stl" files
fname = []
for root,d_names,f_names in os.walk(root_path):
    for f in f_names:
        if f.split('.')[-1] == 'stl':
            fname.append(os.path.join(root, f))

## convert to numpy point cloud
for i in range ( len ( fname ) ):
    print "File path:", fname[i].split("/")[-1]

    try:
    
        meshdata = mesh.Mesh.from_file(fname[i])
        
        pc = pointcloud_from_mesh(meshdata.v0, meshdata.v1, meshdata.v2, n = 100000)
    
        out_file_name = "{}_{:04}".format(class_name, i)

        out_file_path = os.path.join(out_path, out_file_name)

        np.save(out_file_path, pc)

        del pc

        print "Save file:", out_file_name 
    
    except AssertionError:
        
        meshdata_nc_path = os.path.join(root_nc_path, fname[i].split("/")[-1])
        
        os.system( "mv {} {}/".format(fname[i], root_nc_path) )
        
        continue
        
    except ValueError:
        meshdata_nc_path = os.path.join(root_nc_path, fname[i].split("/")[-1])
        
        os.system( "mv {} {}/".format(fname[i], root_nc_path) )
        
        continue
# Out:
# File path: person_0047.stl
# File path: person_0005.stl
# File path: person_0006.stl
# Save file: pedestrian_0002
# File path: person_0007.stl
# File path: person_0008.stl
# File path: person_0009.stl
# File path: person_0012.stl
# File path: person_0020.stl
# Save file: pedestrian_0007
# File path: person_0021.stl
# File path: person_0022.stl
# File path: person_0024.stl
# File path: person_0033.stl
# File path: person_0034.stl
# Save file: pedestrian_0012
# File path: person_0035.stl
# Save file: pedestrian_0013
# File path: person_0036.stl
# Save file: pedestrian_0014
# File path: person_0037.stl
# Save file: pedestrian_0015
# File path: person_0039.stl
# File path: person_0042.stl
# Save file: pedestrian_0017
# File path: person_0053.stl
# File path: person_0055.stl
# File path: person_0056.stl
# File path: person_0057.stl
# File path: person_0061.stl
# File path: person_0064.stl
# File path: person_0065.stl
# Save file: pedestrian_0024
# File path: person_0066.stl
# File path: person_0067.stl
# Save file: pedestrian_0026
# File path: person_0068.stl
# Save file: pedestrian_0027
# File path: person_0069.stl
# Save file: pedestrian_0028
# File path: person_0071.stl
# File path: person_0073.stl
# File path: person_0074.stl
# File path: person_0075.stl
# Save file: pedestrian_0032
# File path: person_0078.stl
# File path: person_0081.stl
# File path: person_0088.stl
# File path: person_0102.stl
