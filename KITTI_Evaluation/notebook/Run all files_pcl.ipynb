# %% [markdown]
# # Run all files

# %% [markdown]
# ## Generation of accumulated point cloud

# %%
"""
Load dataset
"""

import os
import time

start_time = time.time()

data_path = os.path.abspath("parsed_kitti_data_181212.pickle")


import pickle

with open(data_path, 'rb') as f:
    parsed_kitti_data = pickle.load(f)

print "Dataset was loaded"

"""
Data structure
"""

for date in parsed_kitti_data:
    print "date:", date
    
    for drive in parsed_kitti_data[date]:
        print "\tdrive:", drive
# Out:
# Dataset was loaded
# date: 2011_09_26
# 	drive: 0048
# 	drive: 0005
# 	drive: 0059
# 	drive: 0014
# 	drive: 0013
# 	drive: 0002
# 	drive: 0011
# 	drive: 0017
# 	drive: 0051
# 	drive: 0057
# 	drive: 0056
# 	drive: 0009
# 	drive: 0060
# 	drive: 0084
# 	drive: 0018
# 	drive: 0093
# 	drive: 0091
# 	drive: 0001

# %%
import copy
import pickle


parsed_kitti_data_w_r = {}

for date in parsed_kitti_data:
    print "date:", date
    parsed_kitti_data_w_r[date] = {}
    
    for drive in parsed_kitti_data[date]:
                
        print "\tdrive:", drive
        
        parsed_kitti_data_w_r_drive = copy.deepcopy(parsed_kitti_data_w_r)
        
        parsed_kitti_data_w_r_drive[date][drive] = []
        
        for tracklets_list in parsed_kitti_data[date][drive]:
            
            tracklets_list_w_r = {}
            
            print "\t\ttrack: ",
            for key in tracklets_list:
                
                print " ", key,
                tracklets_list_w_r[key] = tracklets_list[key]
                
            print "{}".format(len(tracklets_list[key]))
            
            parsed_kitti_data_w_r_drive[date][drive].append(tracklets_list_w_r)
            
        """ 
        Save pickle
        """
        out_file_nme = "parsed_kitti_data_181212_{}_pcl_icpnl.pickle".format(drive)
        with open(out_file_nme, 'wb') as f:
            pickle.dump(parsed_kitti_data_w_r_drive, f, protocol=2)

        print("\n\nSaved new dataset, protocol=2, {}\n\n".format(out_file_nme))
        del parsed_kitti_data_w_r_drive
            

print "\n\n======================================================="
print "======================================================="        
print "Execution time: {} ".format( time.time() - start_time )
print "======================================================="
print "=======================================================\n\n"
# Out:
# date: 2011_09_26
# 	drive: 0048
# 		track:    type   trans   rot   rect   pc 6
# 		track:    type   trans   rot   rect   pc 6
# 		track:    type   trans   rot   rect   pc 3
# 		track:    type   trans   rot   rect   pc 22
# 		track:    type   trans   rot   rect   pc 22
# 		track:    type   trans   rot   rect   pc 19
# 		track:    type   trans   rot   rect   pc 19
# 		track:    type   trans   rot   rect   pc 18
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0048_pcl_icpnl.pickle
#
#
# 	drive: 0005
# 		track:    type   trans   rot   rect   pc 154
# 		track:    type   trans   rot   rect   pc 154
# 		track:    type   trans   rot   rect   pc 6
# 		track:    type   trans   rot   rect   pc 103
# 		track:    type   trans   rot   rect   pc 9
# 		track:    type   trans   rot   rect   pc 35
# 		track:    type   trans   rot   rect   pc 33
# 		track:    type   trans   rot   rect   pc 33
# 		track:    type   trans   rot   rect   pc 28
# 		track:    type   trans   rot   rect   pc 34
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 16
# 		track:    type   trans   rot   rect   pc 16
# 		track:    type   trans   rot   rect   pc 28
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0005_pcl_icpnl.pickle
#
#
# 	drive: 0059
# 		track:    type   trans   rot   rect   pc 373
# 		track:    type   trans   rot   rect   pc 2
# 		track:    type   trans   rot   rect   pc 8
# 		track:    type   trans   rot   rect   pc 21
# 		track:    type   trans   rot   rect   pc 28
# 		track:    type   trans   rot   rect   pc 39
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 28
# 		track:    type   trans   rot   rect   pc 56
# 		track:    type   trans   rot   rect   pc 52
# 		track:    type   trans   rot   rect   pc 71
# 		track:    type   trans   rot   rect   pc 56
# 		track:    type   trans   rot   rect   pc 80
# 		track:    type   trans   rot   rect   pc 38
# 		track:    type   trans   rot   rect   pc 54
# 		track:    type   trans   rot   rect   pc 35
# 		track:    type   trans   rot   rect   pc 25
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 17
# 		track:    type   trans   rot   rect   pc 28
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 33
# 		track:    type   trans   rot   rect   pc 38
# 		track:    type   trans   rot   rect   pc 54
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 89
# 		track:    type   trans   rot   rect   pc 117
# 		track:    type   trans   rot   rect   pc 148
# 		track:    type   trans   rot   rect   pc 146
# 		track:    type   trans   rot   rect   pc 143
# 		track:    type   trans   rot   rect   pc 85
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 88
# 		track:    type   trans   rot   rect   pc 58
# 		track:    type   trans   rot   rect   pc 128
# 		track:    type   trans   rot   rect   pc 60
# 		track:    type   trans   rot   rect   pc 51
# 		track:    type   trans   rot   rect   pc 47
# 		track:    type   trans   rot   rect   pc 167
# 		track:    type   trans   rot   rect   pc 143
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 35
# 		track:    type   trans   rot   rect   pc 162
# 		track:    type   trans   rot   rect   pc 182
# 		track:    type   trans   rot   rect   pc 54
# 		track:    type   trans   rot   rect   pc 36
# 		track:    type   trans   rot   rect   pc 6
# 		track:    type   trans   rot   rect   pc 45
# 		track:    type   trans   rot   rect   pc 56
# 		track:    type   trans   rot   rect   pc 16
# 		track:    type   trans   rot   rect   pc 103
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 27
# 		track:    type   trans   rot   rect   pc 88
# 		track:    type   trans   rot   rect   pc 75
# 		track:    type   trans   rot   rect   pc 17
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 33
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0059_pcl_icpnl.pickle
#
#
# 	drive: 0014
# 		track:    type   trans   rot   rect   pc 4
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 314
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 29
# 		track:    type   trans   rot   rect   pc 22
# 		track:    type   trans   rot   rect   pc 28
# 		track:    type   trans   rot   rect   pc 33
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 43
# 		track:    type   trans   rot   rect   pc 36
# 		track:    type   trans   rot   rect   pc 48
# 		track:    type   trans   rot   rect   pc 15
# 		track:    type   trans   rot   rect   pc 19
# 		track:    type   trans   rot   rect   pc 22
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 19
# 		track:    type   trans   rot   rect   pc 14
# 		track:    type   trans   rot   rect   pc 19
# 		track:    type   trans   rot   rect   pc 21
# 		track:    type   trans   rot   rect   pc 45
# 		track:    type   trans   rot   rect   pc 21
# 		track:    type   trans   rot   rect   pc 13
# 		track:    type   trans   rot   rect   pc 23
# 		track:    type   trans   rot   rect   pc 14
# 		track:    type   trans   rot   rect   pc 15
# 		track:    type   trans   rot   rect   pc 14
# 		track:    type   trans   rot   rect   pc 3
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 8
# 		track:    type   trans   rot   rect   pc 17
# 		track:    type   trans   rot   rect   pc 18
# 		track:    type   trans   rot   rect   pc 20
# 		track:    type   trans   rot   rect   pc 21
# 		track:    type   trans   rot   rect   pc 27
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 10
# 		track:    type   trans   rot   rect   pc 1
# 		track:    type   trans   rot   rect   pc 12
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 12
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0014_pcl_icpnl.pickle
#
#
# 	drive: 0013
# 		track:    type   trans   rot   rect   pc 76
# 		track:    type   trans   rot   rect   pc 120
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 25
# 		track:    type   trans   rot   rect   pc 25
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 29
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0013_pcl_icpnl.pickle
#
#
# 	drive: 0002
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 28
# 		track:    type   trans   rot   rect   pc 16
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0002_pcl_icpnl.pickle
#
#
# 	drive: 0011
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 90
# 		track:    type   trans   rot   rect   pc 60
# 		track:    type   trans   rot   rect   pc 180
# 		track:    type   trans   rot   rect   pc 75
# 		track:    type   trans   rot   rect   pc 86
# 		track:    type   trans   rot   rect   pc 74
# 		track:    type   trans   rot   rect   pc 110
# 		track:    type   trans   rot   rect   pc 82
# 		track:    type   trans   rot   rect   pc 47
# 		track:    type   trans   rot   rect   pc 3
# 		track:    type   trans   rot   rect   pc 7
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 16
# 		track:    type   trans   rot   rect   pc 79
# 		track:    type   trans   rot   rect   pc 75
# 		track:    type   trans   rot   rect   pc 151
# 		track:    type   trans   rot   rect   pc 151
# 		track:    type   trans   rot   rect   pc 80
# 		track:    type   trans   rot   rect   pc 78
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0011_pcl_icpnl.pickle
#
#
# 	drive: 0017
# 		track:    type   trans   rot   rect   pc 8
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 27
# 		track:    type   trans   rot   rect   pc 25
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0017_pcl_icpnl.pickle
#
#
# 	drive: 0051
# 		track:    type   trans   rot   rect   pc 7
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 28
# 		track:    type   trans   rot   rect   pc 29
# 		track:    type   trans   rot   rect   pc 18
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 6
# 		track:    type   trans   rot   rect   pc 3
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 8
# 		track:    type   trans   rot   rect   pc 6
# 		track:    type   trans   rot   rect   pc 16
# 		track:    type   trans   rot   rect   pc 13
# 		track:    type   trans   rot   rect   pc 8
# 		track:    type   trans   rot   rect   pc 42
# 		track:    type   trans   rot   rect   pc 19
# 		track:    type   trans   rot   rect   pc 121
# 		track:    type   trans   rot   rect   pc 29
# 		track:    type   trans   rot   rect   pc 23
# 		track:    type   trans   rot   rect   pc 91
# 		track:    type   trans   rot   rect   pc 20
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 40
# 		track:    type   trans   rot   rect   pc 69
# 		track:    type   trans   rot   rect   pc 78
# 		track:    type   trans   rot   rect   pc 41
# 		track:    type   trans   rot   rect   pc 61
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 76
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 47
# 		track:    type   trans   rot   rect   pc 44
# 		track:    type   trans   rot   rect   pc 53
# 		track:    type   trans   rot   rect   pc 36
# 		track:    type   trans   rot   rect   pc 51
# 		track:    type   trans   rot   rect   pc 55
# 		track:    type   trans   rot   rect   pc 35
# 		track:    type   trans   rot   rect   pc 65
# 		track:    type   trans   rot   rect   pc 46
# 		track:    type   trans   rot   rect   pc 39
# 		track:    type   trans   rot   rect   pc 41
# 		track:    type   trans   rot   rect   pc 34
# 		track:    type   trans   rot   rect   pc 41
# 		track:    type   trans   rot   rect   pc 54
# 		track:    type   trans   rot   rect   pc 76
# 		track:    type   trans   rot   rect   pc 74
# 		track:    type   trans   rot   rect   pc 209
# 		track:    type   trans   rot   rect   pc 106
# 		track:    type   trans   rot   rect   pc 42
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0051_pcl_icpnl.pickle
#
#
# 	drive: 0057
# 		track:    type   trans   rot   rect   pc 361
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 323
# 		track:    type   trans   rot   rect   pc 18
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 48
# 		track:    type   trans   rot   rect   pc 57
# 		track:    type   trans   rot   rect   pc 319
# 		track:    type   trans   rot   rect   pc 332
# 		track:    type   trans   rot   rect   pc 262
# 		track:    type   trans   rot   rect   pc 35
# 		track:    type   trans   rot   rect   pc 22
# 		track:    type   trans   rot   rect   pc 38
# 		track:    type   trans   rot   rect   pc 43
# 		track:    type   trans   rot   rect   pc 39
# 		track:    type   trans   rot   rect   pc 40
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 33
# 		track:    type   trans   rot   rect   pc 27
# 		track:    type   trans   rot   rect   pc 34
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 27
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 19
# 		track:    type   trans   rot   rect   pc 8
# 		track:    type   trans   rot   rect   pc 10
# 		track:    type   trans   rot   rect   pc 30
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0057_pcl_icpnl.pickle
#
#
# 	drive: 0056
# 		track:    type   trans   rot   rect   pc 294
# 		track:    type   trans   rot   rect   pc 14
# 		track:    type   trans   rot   rect   pc 13
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 25
# 		track:    type   trans   rot   rect   pc 49
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 22
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 18
# 		track:    type   trans   rot   rect   pc 15
# 		track:    type   trans   rot   rect   pc 18
# 		track:    type   trans   rot   rect   pc 18
# 		track:    type   trans   rot   rect   pc 18
# 		track:    type   trans   rot   rect   pc 33
# 		track:    type   trans   rot   rect   pc 12
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 28
# 		track:    type   trans   rot   rect   pc 34
# 		track:    type   trans   rot   rect   pc 33
# 		track:    type   trans   rot   rect   pc 25
# 		track:    type   trans   rot   rect   pc 1
# 		track:    type   trans   rot   rect   pc 14
# 		track:    type   trans   rot   rect   pc 18
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0056_pcl_icpnl.pickle
#
#
# 	drive: 0009
# 		track:    type   trans   rot   rect   pc 3
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 16
# 		track:    type   trans   rot   rect   pc 19
# 		track:    type   trans   rot   rect   pc 41
# 		track:    type   trans   rot   rect   pc 45
# 		track:    type   trans   rot   rect   pc 46
# 		track:    type   trans   rot   rect   pc 41
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 39
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 58
# 		track:    type   trans   rot   rect   pc 20
# 		track:    type   trans   rot   rect   pc 46
# 		track:    type   trans   rot   rect   pc 35
# 		track:    type   trans   rot   rect   pc 20
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 15
# 		track:    type   trans   rot   rect   pc 20
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 25
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 25
# 		track:    type   trans   rot   rect   pc 18
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 6
# 		track:    type   trans   rot   rect   pc 4
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 14
# 		track:    type   trans   rot   rect   pc 21
# 		track:    type   trans   rot   rect   pc 20
# 		track:    type   trans   rot   rect   pc 19
# 		track:    type   trans   rot   rect   pc 35
# 		track:    type   trans   rot   rect   pc 34
# 		track:    type   trans   rot   rect   pc 29
# 		track:    type   trans   rot   rect   pc 21
# 		track:    type   trans   rot   rect   pc 29
# 		track:    type   trans   rot   rect   pc 25
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 41
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 36
# 		track:    type   trans   rot   rect   pc 35
# 		track:    type   trans   rot   rect   pc 34
# 		track:    type   trans   rot   rect   pc 23
# 		track:    type   trans   rot   rect   pc 10
# 		track:    type   trans   rot   rect   pc 5
# 		track:    type   trans   rot   rect   pc 39
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 4
# 		track:    type   trans   rot   rect   pc 18
# 		track:    type   trans   rot   rect   pc 20
# 		track:    type   trans   rot   rect   pc 69
# 		track:    type   trans   rot   rect   pc 34
# 		track:    type   trans   rot   rect   pc 41
# 		track:    type   trans   rot   rect   pc 41
# 		track:    type   trans   rot   rect   pc 38
# 		track:    type   trans   rot   rect   pc 59
# 		track:    type   trans   rot   rect   pc 29
# 		track:    type   trans   rot   rect   pc 38
# 		track:    type   trans   rot   rect   pc 19
# 		track:    type   trans   rot   rect   pc 79
# 		track:    type   trans   rot   rect   pc 34
# 		track:    type   trans   rot   rect   pc 41
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 48
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 35
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 34
# 		track:    type   trans   rot   rect   pc 36
# 		track:    type   trans   rot   rect   pc 28
# 		track:    type   trans   rot   rect   pc 73
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 36
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 42
# 		track:    type   trans   rot   rect   pc 71
# 		track:    type   trans   rot   rect   pc 35
# 		track:    type   trans   rot   rect   pc 10
# 		track:    type   trans   rot   rect   pc 87
# 		track:    type   trans   rot   rect   pc 46
# 		track:    type   trans   rot   rect   pc 41
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 94
# 		track:    type   trans   rot   rect   pc 34
# 		track:    type   trans   rot   rect   pc 13
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 16
# 		track:    type   trans   rot   rect   pc 21
# 		track:    type   trans   rot   rect   pc 12
# 		track:    type   trans   rot   rect   pc 11
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0009_pcl_icpnl.pickle
#
#
# 	drive: 0060
# 		track:    type   trans   rot   rect   pc 40
# 		track:    type   trans   rot   rect   pc 66
# 		track:    type   trans   rot   rect   pc 64
# 		track:    type   trans   rot   rect   pc 78
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0060_pcl_icpnl.pickle
#
#
# 	drive: 0084
# 		track:    type   trans   rot   rect   pc 16
# 		track:    type   trans   rot   rect   pc 84
# 		track:    type   trans   rot   rect   pc 101
# 		track:    type   trans   rot   rect   pc 101
# 		track:    type   trans   rot   rect   pc 91
# 		track:    type   trans   rot   rect   pc 82
# 		track:    type   trans   rot   rect   pc 79
# 		track:    type   trans   rot   rect   pc 69
# 		track:    type   trans   rot   rect   pc 84
# 		track:    type   trans   rot   rect   pc 94
# 		track:    type   trans   rot   rect   pc 8
# 		track:    type   trans   rot   rect   pc 57
# 		track:    type   trans   rot   rect   pc 46
# 		track:    type   trans   rot   rect   pc 272
# 		track:    type   trans   rot   rect   pc 63
# 		track:    type   trans   rot   rect   pc 54
# 		track:    type   trans   rot   rect   pc 70
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 45
# 		track:    type   trans   rot   rect   pc 20
# 		track:    type   trans   rot   rect   pc 25
# 		track:    type   trans   rot   rect   pc 17
# 		track:    type   trans   rot   rect   pc 33
# 		track:    type   trans   rot   rect   pc 39
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 33
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 104
# 		track:    type   trans   rot   rect   pc 44
# 		track:    type   trans   rot   rect   pc 21
# 		track:    type   trans   rot   rect   pc 36
# 		track:    type   trans   rot   rect   pc 44
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 46
# 		track:    type   trans   rot   rect   pc 45
# 		track:    type   trans   rot   rect   pc 8
# 		track:    type   trans   rot   rect   pc 23
# 		track:    type   trans   rot   rect   pc 28
# 		track:    type   trans   rot   rect   pc 55
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 16
# 		track:    type   trans   rot   rect   pc 67
# 		track:    type   trans   rot   rect   pc 25
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 47
# 		track:    type   trans   rot   rect   pc 46
# 		track:    type   trans   rot   rect   pc 47
# 		track:    type   trans   rot   rect   pc 106
# 		track:    type   trans   rot   rect   pc 71
# 		track:    type   trans   rot   rect   pc 56
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 55
# 		track:    type   trans   rot   rect   pc 36
# 		track:    type   trans   rot   rect   pc 16
# 		track:    type   trans   rot   rect   pc 19
# 		track:    type   trans   rot   rect   pc 21
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0084_pcl_icpnl.pickle
#
#
# 	drive: 0018
# 		track:    type   trans   rot   rect   pc 8
# 		track:    type   trans   rot   rect   pc 43
# 		track:    type   trans   rot   rect   pc 46
# 		track:    type   trans   rot   rect   pc 45
# 		track:    type   trans   rot   rect   pc 44
# 		track:    type   trans   rot   rect   pc 49
# 		track:    type   trans   rot   rect   pc 45
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 36
# 		track:    type   trans   rot   rect   pc 70
# 		track:    type   trans   rot   rect   pc 52
# 		track:    type   trans   rot   rect   pc 56
# 		track:    type   trans   rot   rect   pc 136
# 		track:    type   trans   rot   rect   pc 55
# 		track:    type   trans   rot   rect   pc 29
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0018_pcl_icpnl.pickle
#
#
# 	drive: 0093
# 		track:    type   trans   rot   rect   pc 10
# 		track:    type   trans   rot   rect   pc 28
# 		track:    type   trans   rot   rect   pc 53
# 		track:    type   trans   rot   rect   pc 44
# 		track:    type   trans   rot   rect   pc 64
# 		track:    type   trans   rot   rect   pc 69
# 		track:    type   trans   rot   rect   pc 34
# 		track:    type   trans   rot   rect   pc 85
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 36
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 120
# 		track:    type   trans   rot   rect   pc 23
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 61
# 		track:    type   trans   rot   rect   pc 52
# 		track:    type   trans   rot   rect   pc 66
# 		track:    type   trans   rot   rect   pc 75
# 		track:    type   trans   rot   rect   pc 28
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 40
# 		track:    type   trans   rot   rect   pc 23
# 		track:    type   trans   rot   rect   pc 38
# 		track:    type   trans   rot   rect   pc 56
# 		track:    type   trans   rot   rect   pc 97
# 		track:    type   trans   rot   rect   pc 68
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 43
# 		track:    type   trans   rot   rect   pc 49
# 		track:    type   trans   rot   rect   pc 22
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 20
# 		track:    type   trans   rot   rect   pc 59
# 		track:    type   trans   rot   rect   pc 27
# 		track:    type   trans   rot   rect   pc 81
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 41
# 		track:    type   trans   rot   rect   pc 49
# 		track:    type   trans   rot   rect   pc 56
# 		track:    type   trans   rot   rect   pc 49
# 		track:    type   trans   rot   rect   pc 35
# 		track:    type   trans   rot   rect   pc 36
# 		track:    type   trans   rot   rect   pc 54
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 46
# 		track:    type   trans   rot   rect   pc 76
# 		track:    type   trans   rot   rect   pc 85
# 		track:    type   trans   rot   rect   pc 33
# 		track:    type   trans   rot   rect   pc 19
# 		track:    type   trans   rot   rect   pc 90
# 		track:    type   trans   rot   rect   pc 39
# 		track:    type   trans   rot   rect   pc 17
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 68
# 		track:    type   trans   rot   rect   pc 56
# 		track:    type   trans   rot   rect   pc 36
# 		track:    type   trans   rot   rect   pc 51
# 		track:    type   trans   rot   rect   pc 40
# 		track:    type   trans   rot   rect   pc 2
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 40
# 		track:    type   trans   rot   rect   pc 61
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 39
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0093_pcl_icpnl.pickle
#
#
# 	drive: 0091
# 		track:    type   trans   rot   rect   pc 4
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 12
# 		track:    type   trans   rot   rect   pc 20
# 		track:    type   trans   rot   rect   pc 18
# 		track:    type   trans   rot   rect   pc 27
# 		track:    type   trans   rot   rect   pc 2
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 5
# 		track:    type   trans   rot   rect   pc 4
# 		track:    type   trans   rot   rect   pc 4
# 		track:    type   trans   rot   rect   pc 12
# 		track:    type   trans   rot   rect   pc 12
# 		track:    type   trans   rot   rect   pc 18
# 		track:    type   trans   rot   rect   pc 17
# 		track:    type   trans   rot   rect   pc 5
# 		track:    type   trans   rot   rect   pc 7
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 17
# 		track:    type   trans   rot   rect   pc 69
# 		track:    type   trans   rot   rect   pc 8
# 		track:    type   trans   rot   rect   pc 9
# 		track:    type   trans   rot   rect   pc 9
# 		track:    type   trans   rot   rect   pc 11
# 		track:    type   trans   rot   rect   pc 10
# 		track:    type   trans   rot   rect   pc 8
# 		track:    type   trans   rot   rect   pc 9
# 		track:    type   trans   rot   rect   pc 99
# 		track:    type   trans   rot   rect   pc 21
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 30
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 12
# 		track:    type   trans   rot   rect   pc 12
# 		track:    type   trans   rot   rect   pc 40
# 		track:    type   trans   rot   rect   pc 8
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 29
# 		track:    type   trans   rot   rect   pc 52
# 		track:    type   trans   rot   rect   pc 31
# 		track:    type   trans   rot   rect   pc 21
# 		track:    type   trans   rot   rect   pc 15
# 		track:    type   trans   rot   rect   pc 39
# 		track:    type   trans   rot   rect   pc 38
# 		track:    type   trans   rot   rect   pc 27
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 27
# 		track:    type   trans   rot   rect   pc 26
# 		track:    type   trans   rot   rect   pc 24
# 		track:    type   trans   rot   rect   pc 51
# 		track:    type   trans   rot   rect   pc 51
# 		track:    type   trans   rot   rect   pc 12
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 14
# 		track:    type   trans   rot   rect   pc 9
# 		track:    type   trans   rot   rect   pc 14
# 		track:    type   trans   rot   rect   pc 6
# 		track:    type   trans   rot   rect   pc 4
# 		track:    type   trans   rot   rect   pc 9
# 		track:    type   trans   rot   rect   pc 10
# 		track:    type   trans   rot   rect   pc 17
# 		track:    type   trans   rot   rect   pc 2
# 		track:    type   trans   rot   rect   pc 48
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0091_pcl_icpnl.pickle
#
#
# 	drive: 0001
# 		track:    type   trans   rot   rect   pc 13
# 		track:    type   trans   rot   rect   pc 20
# 		track:    type   trans   rot   rect   pc 27
# 		track:    type   trans   rot   rect   pc 108
# 		track:    type   trans   rot   rect   pc 33
# 		track:    type   trans   rot   rect   pc 29
# 		track:    type   trans   rot   rect   pc 32
# 		track:    type   trans   rot   rect   pc 36
# 		track:    type   trans   rot   rect   pc 35
# 		track:    type   trans   rot   rect   pc 46
# 		track:    type   trans   rot   rect   pc 75
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 15
# 		track:    type   trans   rot   rect   pc 37
# 		track:    type   trans   rot   rect   pc 15
#
#
# Saved new dataset, protocol=2, parsed_kitti_data_181212_0001_pcl_icpnl.pickle
#
#
#
#
# =======================================================
# =======================================================
# Execution time: 9.49475216866
# =======================================================
# =======================================================

# %% [markdown]
# ## Registration

# %%
import re

"""
Search all files 
"""
basedir = './'
p = re.compile('parsed_kitti_data_181212_\d{4}_pcl_icpnl')

drives = []

cnt = 0
for root,d_names,f_names in os.walk(basedir):
    for f in f_names:
        m = p.match(f)
        if m:
            cnt +=1
            print 'Match found: ', m.group(), cnt
            drives.append(m.group() + ".pickle")
# Out:
# Match found:  parsed_kitti_data_181212_0084_pcl_icpnl 1
# Match found:  parsed_kitti_data_181212_0011_pcl_icpnl 2
# Match found:  parsed_kitti_data_181212_0057_pcl_icpnl 3
# Match found:  parsed_kitti_data_181212_0018_pcl_icpnl 4
# Match found:  parsed_kitti_data_181212_0001_pcl_icpnl 5
# Match found:  parsed_kitti_data_181212_0091_pcl_icpnl 6
# Match found:  parsed_kitti_data_181212_0005_pcl_icpnl 7
# Match found:  parsed_kitti_data_181212_0093_pcl_icpnl 8
# Match found:  parsed_kitti_data_181212_0059_pcl_icpnl 9
# Match found:  parsed_kitti_data_181212_0056_pcl_icpnl 10
# Match found:  parsed_kitti_data_181212_0009_pcl_icpnl 11
# Match found:  parsed_kitti_data_181212_0048_pcl_icpnl 12
# Match found:  parsed_kitti_data_181212_0002_pcl_icpnl 13
# Match found:  parsed_kitti_data_181212_0060_pcl_icpnl 14
# Match found:  parsed_kitti_data_181212_0017_pcl_icpnl 15
# Match found:  parsed_kitti_data_181212_0014_pcl_icpnl 16
# Match found:  parsed_kitti_data_181212_0013_pcl_icpnl 17
# Match found:  parsed_kitti_data_181212_0051_pcl_icpnl 18

# %%
import tqdm
import sys
import pickle


from registration import *


for d in drives:
    
    if d == 'parsed_kitti_data_181212_0084_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0011_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0057_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0018_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0001_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0091_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0005_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0093_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0059_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0056_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0009_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0048_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0002_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0006_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0017_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0014_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0060_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0013_pcl_icpnl.pickle': continue
    if d == 'parsed_kitti_data_181212_0051_pcl_icpnl.pickle': continue
                        
    
    """
    Load dataset
    """
    with open(d, 'rb') as f:
        parsed_kitti_data_w_r = pickle.load(f)
    

    for date in parsed_kitti_data_w_r:
        print "date:", date
        
        assert len(parsed_kitti_data_w_r[date]) == 1

        for drive in parsed_kitti_data_w_r[date]:
     
            print "\tdrive:", drive

            sys.stdout.flush()

            for i in tqdm.trange( len(parsed_kitti_data_w_r[date][drive]) ):

                pc = parsed_kitti_data_w_r[date][drive][i]['pc']

                """
                Registration
                """
                parsed_kitti_data_w_r[date][drive][i]['pc_wr'] = []
                sys.stdout.flush()
                if len(pc) > 1:
                    parsed_kitti_data_w_r[date][drive][i]['pc_wr'] = registration_pcl(pc, 'pcl_icp_nl')
                else:
                    parsed_kitti_data_w_r[date][drive][i]['pc_wr'] = []

                    print "\tdrive:", drive
                    
    """
    Save data
    """
    out_data_path = 'parsed_kitti_data_w_r_181212_{}_pcl_icpnl.pickle'.format(drive)
    
    with open(out_data_path, 'wb') as f:
        pickle.dump(parsed_kitti_data_w_r, f, protocol=2)
    
    print("\n\nSaved new dataset, protocol=2")
    
print "\n\n======================================================="
print "======================================================="        
print "Execution time: {} ".format( time.time() - start_time )
print "======================================================="
print "=======================================================\n\n"
# Out:
# =======================================================
# =======================================================
# Execution time: 10.140032053
# =======================================================
# =======================================================

# %% [markdown]
# ## Classification

# %%
import os
import re

"""
Search all files 
"""
basedir = './'
p = re.compile('parsed_kitti_data_w_r_181212_\d{4}_pcl_icpnl')

drives = []

cnt = 0
for root,d_names,f_names in os.walk(basedir):
    for f in f_names:
        m = p.match(f)
        if m:
            cnt +=1
            print 'Match found: ', m.group(), cnt
            drives.append(m.group() + ".pickle")
# Out:
# Match found:  parsed_kitti_data_w_r_181212_0059_pcl_icpnl 1
# Match found:  parsed_kitti_data_w_r_181212_0056_pcl_icpnl 2
# Match found:  parsed_kitti_data_w_r_181212_0001_pcl_icpnl 3
# Match found:  parsed_kitti_data_w_r_181212_0093_pcl_icpnl 4
# Match found:  parsed_kitti_data_w_r_181212_0018_pcl_icpnl 5
# Match found:  parsed_kitti_data_w_r_181212_0013_pcl_icpnl 6
# Match found:  parsed_kitti_data_w_r_181212_0060_pcl_icpnl 7
# Match found:  parsed_kitti_data_w_r_181212_0011_pcl_icpnl 8
# Match found:  parsed_kitti_data_w_r_181212_0084_pcl_icpnl 9
# Match found:  parsed_kitti_data_w_r_181212_0048_pcl_icpnl 10
# Match found:  parsed_kitti_data_w_r_181212_0002_pcl_icpnl 11
# Match found:  parsed_kitti_data_w_r_181212_0017_pcl_icpnl 12

# %%
import tqdm
import sys
import pickle
import os, sys
import tensorflow as tf

from registration import *

""" 
Import model 
"""
sys.path.append( os.path.abspath('../../Network/model') )
from train import *
import model_out_5_heading_3_relu as MODEL
model_path = os.path.abspath('../../Network/notebook/train_log_20181208/model_out_1/model009.ckpt')

def NormalizeResample(data, num_sample):
    """ data is in N x ...
    we want to keep num_samplexC of them.
    if N > num_sample, we will randomly keep num_sample of them.
    if N < num_sample, we will randomly duplicate samples.
    """
  

    ## normalizing    
    min_val = np.min(data, axis = 0)
    
    data[:,0] = data[:,0] - min_val[0]
    data[:,1] = data[:,1] - min_val[1]
    data[:,2] = data[:,2] - min_val[2]
      
    max_val = np.max(data)
    
    data[:,0] = data[:,0] / max_val
    data[:,1] = data[:,1] / max_val
    data[:,2] = data[:,2] / max_val
                 
        
    ## resampling
    N = data.shape[0]
    if (N == num_sample):
        return data
    elif (N > num_sample):
        sample = np.random.choice(N, num_sample)
        return data[sample, ...]
    else:
        sample = np.random.choice(N, num_sample-N)
        dup_data = data[sample, ...]
        return np.concatenate([data, dup_data], 0)

    
    
# for d in drives:
    
def run_classification(d):
    """
    Load dataset
    """
    
    with open(d, 'rb') as f:
        parsed_kitti_data_w_r = pickle.load(f)

        """
        Classification
        """

        is_training = False

        GPU_INDEX = 0
        NUM_POINT = 1024
        NUM_CLASSES = 3
        BATCH_SIZE = 1

        # reset graph
        tf.reset_default_graph()

        with tf.device('/gpu:'+str(GPU_INDEX)):
            pointclouds_pl, labels_pl, heading_labels_pl = MODEL.placeholder_inputs(BATCH_SIZE, NUM_POINT)
            is_training_pl = tf.placeholder(tf.bool, shape=())

            # simple model
            pred, end_points = MODEL.get_model(pointclouds_pl, is_training_pl)

            # Add ops to save and restore all the variables.
            saver = tf.train.Saver()

        # Create a session
        config = tf.ConfigProto()
        config.gpu_options.allow_growth = True
        config.allow_soft_placement = True
        config.log_device_placement = True

        ops = {'pointclouds_pl': pointclouds_pl,
               'is_training_pl': is_training_pl,
               'pred': pred}

        # ops.reset_default_graph() 

        sess = tf.Session(config=config)

        # Restore variables from disk.
        saver.restore(sess, model_path)

        print "Model restored"
        sys.stdout.flush()


        for date in parsed_kitti_data_w_r:
            print "date:", date

            for drive in parsed_kitti_data_w_r[date]:
                print "\tdrive:", drive

                for i in range( len(parsed_kitti_data_w_r[date][drive]) ):
                    
                    clusters = parsed_kitti_data_w_r[date][drive][i]['pc_wr']
                    parsed_kitti_data_w_r[date][drive][i]['cls_wr'] = []
                    for j in tqdm.trange(len(clusters)):

                        if len(clusters[j]) == 0:
                            continue

                        current_data = NormalizeResample(clusters[j], NUM_POINT)
                        feed_dict = {ops['pointclouds_pl']: current_data.reshape((BATCH_SIZE, NUM_POINT, 3)),
                                     ops['is_training_pl']: is_training}
                        pred_val = sess.run([ops['pred']], feed_dict=feed_dict )

                        cls = np.argmax(pred_val[0][:3], 1)
                        parsed_kitti_data_w_r[date][drive][i]['cls_wr'].append(cls)

                    clusters = parsed_kitti_data_w_r[date][drive][i]['pc']
                    parsed_kitti_data_w_r[date][drive][i]['cls'] = []
                    for j in tqdm.trange(len(clusters)):

                        if len(clusters[j]) == 0:
                            continue
                        current_data = NormalizeResample(clusters[j][:,:3], NUM_POINT)
                        feed_dict = {ops['pointclouds_pl']: current_data.reshape((BATCH_SIZE, NUM_POINT, 3)),
                                     ops['is_training_pl']: is_training}
                        pred_val = sess.run([ops['pred']], feed_dict=feed_dict )

                        cls = np.argmax(pred_val[0][:3], 1)
                        parsed_kitti_data_w_r[date][drive][i]['cls'].append(cls)
                    
    """
    Save data
    """
    out_data_path = 'parsed_kitti_data_w_r_c_181212_{}_pcl_icpnl.pickle'.format(drive)
    
    with open(out_data_path, 'wb') as f:
        pickle.dump(parsed_kitti_data_w_r, f, protocol=2)
    
    print("\n\nSaved new dataset, protocol=2")

# %%
import multiprocessing

# option 1: execute code with extra process

## arguments: out_path, trained_model = None, hlw = 0.1, max_epoch = 1):

for d in drives:

    p = multiprocessing.Process( target=run_classification, args = (d,) )

    p.start()
    p.join()
# Out:
# INFO:tensorflow:Restoring parameters from /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181208/model_out_1/model009.ckpt
# Model restored
# date: 2011_09_26
# 	drive: 0059
# 100%|██████████| 373/373 [00:04<00:00, 80.72it/s]
# 100%|██████████| 373/373 [00:03<00:00, 106.00it/s]
# 100%|██████████| 2/2 [00:00<00:00, 66.58it/s]
# 100%|██████████| 2/2 [00:00<00:00, 66.71it/s]
# 100%|██████████| 8/8 [00:00<00:00, 71.21it/s]
# 100%|██████████| 8/8 [00:00<00:00, 71.36it/s]
# 100%|██████████| 21/21 [00:00<00:00, 79.99it/s]
# 100%|██████████| 21/21 [00:00<00:00, 79.99it/s]
# 100%|██████████| 28/28 [00:00<00:00, 89.58it/s]
# 100%|██████████| 28/28 [00:00<00:00, 106.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 71.53it/s]
# 100%|██████████| 39/39 [00:00<00:00, 107.51it/s]
# 100%|██████████| 11/11 [00:00<00:00, 98.23it/s]
# 100%|██████████| 11/11 [00:00<00:00, 97.92it/s]
# 100%|██████████| 28/28 [00:00<00:00, 106.59it/s]
# 100%|██████████| 28/28 [00:00<00:00, 106.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 71
19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 71.52it/s]
# 100%|██████████| 44/44 [00:00<00:00, 95.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 70.38it/s]
# 100%|██████████| 30/30 [00:00<00:00, 82.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 72.93it/s]
# 100%|██████████| 46/46 [00:00<00:00, 89.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 67.98it/s]
# 100%|██████████| 45/45 [00:00<00:00, 97.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 71.99it/s]
# 100%|██████████| 8/8 [00:00<00:00, 71.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 65.39it/s]
# 100%|██████████| 23/23 [00:00<00:00, 87.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 71.71it/s]
# 100%|██████████| 28/28 [00:00<00:00, 106.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 71.69it/s]
# 100%|██████████| 55/55 [00:00<00:00, 106.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 71.67it/s]
# 100%|██████████| 30/30 [00:00<00:00, 96.00it/s]
# 100%|██████████| 16/16 [00:00<00:00, 97.85it/s]
# 100%|██████████| 16/16 [00:00<00:00, 75.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 71.88it/s]
# 100%|██████████| 67/67 [00:00<00:00, 93.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 66.28it/s]
# 100%|██████████| 25/25 [00:00<00:00, 95.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 71.80it/s]
# 100%|██████████| 37/37 [00:00<00:00, 89.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 71.20it/s]
# 100%|██████████| 47/47 [00:00<00:00, 101.54it/s]
# 100%|██████████| 1/1 [00:00<00:00, 70.66it/s]
# 100%|██████████| 46/46 [00:00<00:00, 111.51it/s]
# 100%|██████████| 1/1 [00:00<00:00, 72.01it/s]
# 100%|██████████| 47/47 [00:00<00:00, 101.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 66.34it/s]
# 100%|██████████| 106/106 [00:01<00:00, 99.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 72.10it/s]
# 100%|██████████| 71/71 [00:00<00:00, 94.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 70.82it/s]
# 100%|██████████| 56/56 [00:00<00:00, 91.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 71.94it/s]
# 100%|██████████| 26/26 [00:00<00:00, 99.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 71.78it/s]
# 100%|██████████| 55/55 [00:00<00:00, 89.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 72.06it/s]
# 100%|██████████| 36/36 [00:00<00:00, 87.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 72.15it/s]
# 100%|██████████| 16/16 [00:00<00:00, 75.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 72.28it/s]
# 100%|██████████| 19/19 [00:00<00:00, 89.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 66.69it/s]
# 100%|██████████| 21/21 [00:00<00:00, 98.29it/s]
# Saved new dataset, protocol=2
# INFO:tensorflow:Restoring parameters from /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181208/model_out_1/model009.ckpt
# Model restored
# date: 2011_09_26
# 	drive: 0048
# 100%|██████████| 6/6 [00:01<00:00,  4.94it/s]
# 100%|██████████| 6/6 [00:00<00:00, 103.96it/s]
# 100%|██████████| 6/6 [00:00<00:00, 53.55it/s]
# 100%|██████████| 6/6 [00:00<00:00, 53.47it/s]
# 100%|██████████| 3/3 [00:00<00:00, 48.36it/s]
# 100%|██████████| 3/3 [00:00<00:00, 48.17it/s]
# 100%|██████████| 22/22 [00:00<00:00, 83.68it/s]
# 100%|██████████| 22/22 [00:00<00:00, 83.46it/s]
# 100%|██████████| 1/1 [00:00<00:00, 72.09it/s]
# 100%|██████████| 22/22 [00:00<00:00, 83.85it/s]
# 100%|██████████| 19/19 [00:00<00:00, 89.40it/s]
# 100%|██████████| 19/19 [00:00<00:00, 89.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 71.72it/s]
# 100%|██████████| 19/19 [00:00<00:00, 89.47it/s]
# 100%|██████████| 1/1 [00:00<00:00, 612.75it/s]
# 100%|██████████| 18/18 [00:00<00:00, 110.73it/s]
# Saved new dataset, protocol=2
# INFO:tensorflow:Restoring parameters from /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181208/model_out_1/model009.ckpt
# Model restored
# date: 2011_09_26
# 	drive: 0002
# 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
# 100%|██████████| 11/11 [00:00<00:00, 105.74it/s]
# 100%|██████████| 28/28 [00:00<00:00, 89.54it/s]
# 100%|██████████| 28/28 [00:00<00:00, 89.57it/s]
# 100%|██████████| 16/16 [00:00<00:00, 98.74it/s]
# 100%|██████████| 16/16 [00:00<00:00, 98.35it/s]
# Saved new dataset, protocol=2
# INFO:tensorflow:Restoring parameters from /home/gozilla/kyungpyo/git/MasterThesisProject/Network/notebook/train_log_20181208/model_out_1/model009.ckpt
# Model restored
# date: 2011_09_26
# 	drive: 0017
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s]
# 100%|██████████| 8/8 [00:00<00:00, 70.64it/s]
# 100%|██████████| 24/24 [00:00<00:00, 91.49it/s]
# 100%|██████████| 24/24 [00:00<00:00, 91.34it/s]
# 100%|██████████| 27/27 [00:00<00:00, 102.86it/s]
# 100%|██████████| 27/27 [00:00<00:00, 101.90it/s]
# 100%|██████████| 25/25 [00:00<00:00, 117.33it/s]
# 100%|██████████| 25/25 [00:00<00:00, 95.26it/s]
# Saved new dataset, protocol=2

# %%
print "\n\n======================================================="
print "======================================================="        
print "Execution time: {} ".format( time.time() - start_time )
print "======================================================="
print "=======================================================\n\n"
# Out:
# =======================================================
# =======================================================
# Execution time: 239.952139139
# =======================================================
# =======================================================
